# %% [markdown]
# # TREC 2018 Precision Medicine

# %%
import json
from json2html import *
from IPython.display import HTML
import eval
import pandas

# %% [raw]
# Load and show configuration

# %%
with open('config.json', 'r') as f:
    config = json.load(f)
#HTML(json2html.convert(json = config))

# %%
topics_all = eval.get_topics('./topics/topics2017.xml')
qrels_all = eval.get_qrels('./gold-standard/abstracts.2017.qrels')
TOPIC = 2

# %%
topic = topics_all[(topics_all.topic==TOPIC)]
qrels = eval.qrels_of_topics(qrels_all, topic)
topic
# Out:
#    topic       disease                       gene        gene1          gene2  \
# 2      2  Colon cancer  KRAS (G13D), BRAF (V600E)  KRAS (G13D)   BRAF (V600E)
#
#   gene3   sex age
# 2        male  52

# %%
run, params = eval.run(topic)
params['query_template'] = 'topic-optimized.json'
run, params = eval.run(topic, params)
# Out:
# RUN: FIXME TOPICS: 1 {'query_template': 'baseline.json', 'disease_tie_breaker': 0.5, 'disease_boost': 1.5, 'gene_tie_breaker': 0.5, 'gene_boost': 1}
# RUN: FIXME TOPICS: 1 {'query_template': 'topic-optimized.json', 'disease_tie_breaker': 0.5, 'disease_boost': 1.5, 'gene_tie_breaker': 0.5, 'gene_boost': 1}

# %%
results, aggregated = eval.evaluate(qrels[(qrels.relev.isin([2]))], run)
run
# Out:
#      TOPIC_NO  Q0               ID  RANK      SCORE RUN_NAME  \
# 0           2  Q0         25367198     1  74.864555    FIXME
# 1           2  Q0         23157824     2  73.092110    FIXME
# 2           2  Q0         20162668     3  72.850525    FIXME
# 3           2  Q0         24964758     4  71.389040    FIXME
# 4           2  Q0         27340238     5  70.217780    FIXME
# 5           2  Q0         26005817     6  68.848930    FIXME
# 6           2  Q0         24925349     7  68.778660    FIXME
# 7           2  Q0         19881948     8  67.829895    FIXME
# 8           2  Q0         19424571     9  67.009630    FIXME
# 9           2  Q0         26716438    10  65.959435    FIXME
# 10          2  Q0         23033302    11  65.933556    FIXME
# 11          2  Q0         20501503    12  65.928460    FIXME
# 12          2  Q0   AACR_2013-3381    13  64.561430    FIXME
# 13          2  Q0         26376292    14  61.480670    FIXME
# 14          2  Q0         23157823    15  61.307564    FIXME
# 15          2  Q0         22281684    16  61.220440    FIXME
# 16          2  Q0         24832158    17  60.337340    FIXME
# 17          2  Q0         24861115    18  60.333540    FIXME
# 18          2  Q0         26160882    19  58.416206    FIXME
# 19          2  Q0         25305506    20  58.170944    FIXME
# 20          2  Q0         23887306    21  58.134430    FIXME
# 21          2  Q0         19843849    22  57.588520    FIXME
# 22          2  Q0   AACR_2012-1151    23  57.389133    FIXME
# 23          2  Q0         24889488    24  57.219880    FIXME
# 24          2  Q0    ASCO_34230-65    25  56.982567    FIXME
# 25          2  Q0         25267307    26  56.677242    FIXME
# 26          2  Q0         25899003    27  56.312416    FIXME
# 27          2  Q0         23825589    28  56.117570    FIXME
# 28          2  Q0         26768652    29  55.856490    FIXME
# 29          2  Q0         19913317    30  55.846940    FIXME
# ..        ...  ..              ...   ...        ...      ...
# 970         2  Q0   AACR_2016-4260   971  33.549970    FIXME
# 971         2  Q0         21618350   972  33.549400    FIXME
# 972         2  Q0         17006850   973  33.538704    FIXME
# 973         2  Q0         26872400   974  33.538437    FIXME
# 974         2  Q0         21741959   975  33.509570    FIXME
# 975         2  Q0         22570761   976  33.493996    FIXME
# 976         2  Q0   AACR_2013-1934   977  33.485863    FIXME
# 977         2  Q0   AACR_2015-1119   978  33.483353    FIXME
# 978         2  Q0         19549773   979  33.480320    FIXME
# 979         2  Q0   AACR_2017-3237   980  33.478855    FIXME
# 980         2  Q0         26824186   981  33.471703    FIXME
# 981         2  Q0         24954536   982  33.452988    FIXME
# 982         2  Q0   AACR_2016-1012   983  33.446156    FIXME
# 983         2  Q0         25469291   984  33.446140    FIXME
# 984         2  Q0         20473912   985  33.444744    FIXME
# 985         2  Q0  ASCO_190873-199   986  33.431152    FIXME
# 986         2  Q0         27270901   987  33.429314    FIXME
# 987         2  Q0  ASCO_176399-195   988  33.422420    FIXME
# 988         2  Q0         24362353   989  33.393894    FIXME
# 989         2  Q0  ASCO_129544-144   990  33.392510    FIXME
# 990         2  Q0         15542810   991  33.385437    FIXME
# 991         2  Q0   AACR_2012-3851   992  33.379960    FIXME
# 992         2  Q0         25065594   993  33.364197    FIXME
# 993         2  Q0   AACR_2015-4691   994  33.359740    FIXME
# 994         2  Q0         19908233   995  33.346066    FIXME
# 995         2  Q0         20962618   996  33.335823    FIXME
# 996         2  Q0   AACR_2016-3135   997  33.331825    FIXME
# 997         2  Q0         22287190   998  33.331436    FIXME
# 998         2  Q0         26392228   999  33.310177    FIXME
# 999         2  Q0         23668556  1000  33.265580    FIXME
#
#                                                  TITLE
# 0    BRAF V600E mutation and KRAS codon 13 mutation...
# 1    [KRAS and BRAF gene mutations in correlation w...
# 2    Combined analysis of specific KRAS mutation, B...
# 3    The prognostic role of microsatellite instabil...
# 4    Oncogenic KRAS and BRAF Drive Metabolic Reprog...
# 5       [Molecular analysis of sporadic colon cancer].
# 6    Patient and tumor characteristics and BRAF and...
# 7    BRAF(V600E) efficient transformation and induc...
# 8    Analysis of a correlation between the BRAF V60...
# 9    The prognostic value of Microsatellite Instabi...
# 10   KRAS and BRAF mutations in Serbian patients wi...
# 11   The BRAF V600E mutation is an independent prog...
# 12   Overcoming resistance to BRAF inhibitors in co...
# 13   Prognostic value of BRAF and KRAS mutation sta...
# 14   [Mutations of KRAS and BRAF in Chinese patient...
# 15   Unresponsiveness of colon cancer to BRAF(V600E...
# 16   Detection of the BRAF V600E mutation in colon ...
# 17   [BRAF gene mutation in wild-type KRAS patients...
# 18   Racial Differences in BRAF\/KRAS Mutation Rate...
# 19   Molecular markers identify subtypes of stage I...
# 20   Improved molecular classification of serrated ...
# 21   Oncogenic KRAS and BRAF differentially regulat...
# 22   cMYC amplification in colon cancer: A novel as...
# 23   KRAS mutation is associated with worse prognos...
# 24   Preliminary report of the mutation status of K...
# 25   KRAS and BRAF mutational status in colon cance...
# 26   TFF2-CXCR4 Axis Is Associated with BRAF V600E ...
# 27   Lkb1 loss promotes tumor progression of BRAF(V...
# 28   Prognostic Effect of BRAF and KRAS Mutations i...
# 29   KRAS and BRAF mutations in patients with recta...
# ..                                                 ...
# 970  3D colorectal cancer organoids as preclinical ...
# 971  Relative role of methylator and tumor suppress...
# 972  [BRAF initiating mutations in the papillary th...
# 973  Molecular Biomarkers in the Personalized Treat...
# 974  Differential detection of KRAS mutations in co...
# 975  Hyperplastic Polyposis Syndrome Identified wit...
# 976  Novel mutation and hypomethylation define dist...
# 977  Subclonal structure of breast cancer subtypes ...
# 978  A cohort study of cyclin D1 expression and pro...
# 979  Development of direct inhibitors of KRAS mutan...
# 980  miR-143 or miR-145 overexpression increases ce...
# 981  KRAS and YAP1 converge to regulate EMT and tum...
# 982  Systems analysis of colon cancer cell metaboli...
# 983  Association between specific KRAS mutations an...
# 984  De novo constitutional MLH1 epimutations confe...
# 985  Genomic profiling of young adults with colorec...
# 986  Comparison of KRAS mutation status between pri...
# 987  Parallel sequencing of a 50 genes panel in met...
# 988  Autophagy promotes BrafV600E-driven lung tumor...
# 989  Updated analysis of KRAS\/NRAS and BRAF mutati...
# 990  Colorectal cancer with mutation in BRAF, KRAS,...
# 991  Killing of Kras mutant colon cancer cells by t...
# 992  Differential in vivo tumorigenicity of diverse...
# 993  KRAS mutation specific alkylating pyrrole-imid...
# 994  Clinicopathological and protein characterizati...
# 995  Benign serrated colorectal fibroblastic polyps...
# 996  Prediction of acquired resistance in colorecta...
# 997  Colorectal serrated adenocarcinoma shows a dif...
# 998  TGF\u03B2 induces epithelial-mesenchymal trans...
# 999  Progress in molecular-based management of diff...
#
# [1000 rows x 7 columns]

# %%
aggregated
# Out:
# {'recall_1000': 0.8205, 'ndcg': 0.7551, 'Rprec': 0.4231, 'P_10': 0.9}

# %% [markdown]
# Check relevant documents missed and why (for topic 2 for example)

# %%
run_set = set(run[(run.TOPIC_NO==TOPIC)].ID)
qrels_set = set(qrels[(qrels.relev.isin([2]))].doc_id)
qrels_set.difference(run_set)
# Out:
# {'15735008',
#  '17517901',
#  '18097554',
#  '18098337',
#  '21457162',
#  '21681432',
#  '22899370',
#  '22972628',
#  '23015072',
#  '23071293',
#  '23112547',
#  '23375249',
#  '23462926',
#  '23763264',
#  '24522186',
#  '24778007',
#  '24805134',
#  '25073438',
#  '25696788',
#  '25924923',
#  '26184520',
#  '26371285',
#  '26623049',
#  '27099668',
#  'AACR_2014-2009',
#  'AACR_2017-4639',
#  'AACR_2017-5162',
#  'ASCO_60628-101'}
