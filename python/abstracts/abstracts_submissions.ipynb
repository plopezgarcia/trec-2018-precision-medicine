# %% [markdown]
# # TREC 2018 Precision Medicine

# %%
import json
from json2html import *
from IPython.display import HTML
import pandas

import os, sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from trec_utils import utils, running, evaluation

# %%
config = utils.load_config()

# %%
topics_2017 = utils.get_topics('./topics/topics2017.xml')
qrels_2017 = utils.get_qrels('./gold-standard/abstracts.2017.qrels')
topics_2017
# Out:
#     topic                           disease                              gene  \
# 1       1                       Liposarcoma                CDK4 Amplification
# 2       2                      Colon cancer         KRAS (G13D), BRAF (V600E)
# 3       3                        Meningioma            NF2 (K322), AKT1(E17K)
# 4       4                     Breast cancer  FGFR1 Amplification, PTEN (Q171)
# 5       5                          Melanoma     BRAF (V600E), CDKN2A Deletion
# 6       6                          Melanoma                       NRAS (Q61K)
# 7       7                       Lung cancer                      EGFR (L858R)
# 8       8                       Lung cancer        EML4-ALK Fusion transcript
# 9       9    Gastrointestinal stromal tumor         KIT Exon 9 (A502_Y503dup)
# 10     10               Lung adenocarcinoma                       KRAS (G12C)
# 11     11                    Gastric cancer                    PIK3CA (E545K)
# 12     12                      Colon cancer                      BRAF (V600E)
# 13     13                Cholangiocarcinoma                             BRCA2
# 14     14                Cholangiocarcinoma                      IDH1 (R132H)
# 15     15                   Cervical cancer                             STK11
# 16     16                 Pancreatic cancer                            CDKN2A
# 17     17                   Prostate cancer                 PTEN Inactivating
# 18     18                 Pancreatic cancer                CDK6 Amplification
# 19     19                 Colorectal cancer               FGFR1 Amplification
# 20     20                       Liposarcoma                MDM2 Amplification
# 21     21               Lung adenocarcinoma                        ALK Fusion
# 22     22                       Lung cancer               ERBB2 Amplification
# 23     23                     Breast cancer                         PTEN Loss
# 24     24                       Lung cancer                             NTRK1
# 25     25               Lung adenocarcinoma                 MET Amplification
# 26     26                     Breast cancer                NRAS Amplification
# 27     27         Pancreatic adenocarcinoma                        KRAS, TP53
# 28     28  Pancreatic ductal adenocarcinoma                             ERBB3
# 29     29               Ampullary carcinoma                              KRAS
# 30     30         Pancreatic adenocarcinoma                   RB1, TP53, KRAS
#
#                          gene1             gene2  gene3     sex age age_group
# 1           CDK4 Amplification                             male  38     adult
# 2                  KRAS (G13D)      BRAF (V600E)           male  52      aged
# 3                   NF2 (K322)        AKT1(E17K)         female  45      aged
# 4          FGFR1 Amplification       PTEN (Q171)         female  67      aged
# 5                 BRAF (V600E)   CDKN2A Deletion         female  45      aged
# 6                  NRAS (Q61K)                             male  55      aged
# 7                 EGFR (L858R)                           female  50      aged
# 8   EML4-ALK Fusion transcript                             male  52      aged
# 9    KIT Exon 9 (A502_Y503dup)                           female  49      aged
# 10                 KRAS (G12C)                           female  61      aged
# 11              PIK3CA (E545K)                             male  54      aged
# 12                BRAF (V600E)                             male  35     adult
# 13                       BRCA2                             male  72      aged
# 14                IDH1 (R132H)                             male  64      aged
# 15                       STK11                           female  26     adult
# 16                      CDKN2A                             male  54      aged
# 17           PTEN Inactivating                             male  81      aged
# 18          CDK6 Amplification                             male  48      aged
# 19         FGFR1 Amplification                           female  35     adult
# 20          MDM2 Amplification                             male  26     adult
# 21                  ALK Fusion                           female  64      aged
# 22         ERBB2 Amplification                             male  70      aged
# 23                   PTEN Loss                           female  54      aged
# 24                       NTRK1                           female  58      aged
# 25           MET Amplification                             male  48      aged
# 26          NRAS Amplification                           female  35     adult
# 27                        KRAS              TP53         female  49      aged
# 28                       ERBB3                           female  73      aged
# 29                        KRAS                             male  61      aged
# 30                         RB1              TP53   KRAS  female  57      aged

# %%
topics_2018 = utils.get_topics('./topics/topics2018.xml')
topics_2018
# Out:
#     topic                                disease  \
# 1       1                               melanoma
# 2       2                               melanoma
# 3       3                               melanoma
# 4       4                               melanoma
# 5       5                               melanoma
# 6       6                               melanoma
# 7       7                               melanoma
# 8       8                               melanoma
# 9       9                               melanoma
# 10     10                               melanoma
# 11     11                               melanoma
# 12     12                               melanoma
# 13     13                               melanoma
# 14     14                               melanoma
# 15     15                               melanoma
# 16     16                               melanoma
# 17     17                               melanoma
# 18     18                               melanoma
# 19     19                               melanoma
# 20     20                               melanoma
# 21     21                               melanoma
# 22     22                               melanoma
# 23     23                               melanoma
# 24     24                               melanoma
# 25     25                               melanoma
# 26     26                      colorectal cancer
# 27     27            medullary thyroid carcinoma
# 28     28                          neuroblastoma
# 29     29                      esophageal cancer
# 30     30                            lung cancer
# 31     31  head and neck squamous cell carcinoma
# 32     32                               leukemia
# 33     33                         gastric cancer
# 34     34                                sarcoma
# 35     35                          breast cancer
# 36     36                            lung cancer
# 37     37               non-small cell carcinoma
# 38     38                     cholangiocarcinoma
# 39     39         anaplastic large cell lymphoma
# 40     40                          breast cancer
# 41     41            papillary thyroid carcinoma
# 42     42                           glioblastoma
# 43     43                   basal cell carcinoma
# 44     44                                 glioma
# 45     45                         thyroid cancer
# 46     46                            lung cancer
# 47     47                        prostate cancer
# 48     48               adenoid cystic carcinoma
# 49     49                 acute myeloid leukemia
# 50     50                 acute myeloid leukemia
#
#                                                  gene  \
# 1                                        BRAF (V600E)
# 2                                        BRAF (V600K)
# 3                                        BRAF (V600R)
# 4                                        BRAF (K601E)
# 5                 BRAF (V600E), PTEN loss of function
# 6                           BRAF (V600E), NRAS (Q61R)
# 7                                  BRAF amplification
# 8                                         NRAS (Q61R)
# 9                                         NRAS (Q61L)
# 10                                        KIT (L576P)
# 11                     KIT (L576P), KIT amplification
# 12                                        KIT (K642E)
# 13                                        KIT (N822Y)
# 14                                  KIT amplification
# 15                                     NF1 truncation
# 16                                NTRK1 rearrangement
# 17                              TP53 loss of function
# 18  tumor cells with >50% membranous PD-L1 expression
# 19          tumor cells negative for PD-L1 expression
# 20                       high tumor mutational burden
# 21           extensive tumor infiltrating lymphocytes
# 22                  no tumor infiltrating lymphocytes
# 23                              PTEN loss of function
# 24                               APC loss of function
# 25                              high serum LDH levels
# 26                                               NRAS
# 27                                                RET
# 28                                                ALK
# 29                                               EGFR
# 30                                               ROS1
# 31                                             CDKN2A
# 32                                               ABL1
# 33                                               EGFR
# 34                                               MDM2
# 35                                             CDKN2A
# 36                                              ERBB2
# 37                                                MET
# 38                                               IDH1
# 39                                                ALK
# 40                                              ERBB2
# 41                                              NTRK1
# 42                                               CDK6
# 43                                              PTCH1
# 44                                               BRAF
# 45                                               BRAF
# 46                                              FGFR1
# 47                                               PTEN
# 48                                                KIT
# 49                                               IDH1
# 50                                               FLT3
#
#                                                 gene1                   gene2  \
# 1                                        BRAF (V600E)
# 2                                        BRAF (V600K)
# 3                                        BRAF (V600R)
# 4                                        BRAF (K601E)
# 5                                        BRAF (V600E)   PTEN loss of function
# 6                                        BRAF (V600E)             NRAS (Q61R)
# 7                                  BRAF amplification
# 8                                         NRAS (Q61R)
# 9                                         NRAS (Q61L)
# 10                                        KIT (L576P)
# 11                                        KIT (L576P)       KIT amplification
# 12                                        KIT (K642E)
# 13                                        KIT (N822Y)
# 14                                  KIT amplification
# 15                                     NF1 truncation
# 16                                NTRK1 rearrangement
# 17                              TP53 loss of function
# 18  tumor cells with >50% membranous PD-L1 expression
# 19          tumor cells negative for PD-L1 expression
# 20                       high tumor mutational burden
# 21           extensive tumor infiltrating lymphocytes
# 22                  no tumor infiltrating lymphocytes
# 23                              PTEN loss of function
# 24                               APC loss of function
# 25                              high serum LDH levels
# 26                                               NRAS
# 27                                                RET
# 28                                                ALK
# 29                                               EGFR
# 30                                               ROS1
# 31                                             CDKN2A
# 32                                               ABL1
# 33                                               EGFR
# 34                                               MDM2
# 35                                             CDKN2A
# 36                                              ERBB2
# 37                                                MET
# 38                                               IDH1
# 39                                                ALK
# 40                                              ERBB2
# 41                                              NTRK1
# 42                                               CDK6
# 43                                              PTCH1
# 44                                               BRAF
# 45                                               BRAF
# 46                                              FGFR1
# 47                                               PTEN
# 48                                                KIT
# 49                                               IDH1
# 50                                               FLT3
#
#    gene3     sex age   age_group
# 1           male  64        aged
# 2           male  54        aged
# 3           male  80        aged
# 4           male  38       adult
# 5           male  57        aged
# 6           male  67        aged
# 7           male  61        aged
# 8         female  63        aged
# 9         female  34       adult
# 10        female  65        aged
# 11        female  56        aged
# 12        female  62        aged
# 13        female  39       adult
# 14        female  66        aged
# 15          male  70        aged
# 16          male  60        aged
# 17          male  72        aged
# 18        female  48        aged
# 19          male  73        aged
# 20        female  86        aged
# 21          male  49        aged
# 22        female  74        aged
# 23          male  68        aged
# 24          male  47        aged
# 25        female  69        aged
# 26          male  49        aged
# 27        female  45        aged
# 28        female   4       child
# 29          male  67        aged
# 30        female  71        aged
# 31          male  64        aged
# 32        female   4       child
# 33        female  60        aged
# 34        female  78        aged
# 35        female  73        aged
# 36        female  49        aged
# 37          male  68        aged
# 38          male  50        aged
# 39          male  18       adult
# 40        female  56        aged
# 41        female  46        aged
# 42          male  84        aged
# 43        female  56        aged
# 44          male  82        aged
# 45        female  40       adult
# 46          male  57        aged
# 47          male  70        aged
# 48        female  58        aged
# 49          male   1     newborn
# 50          male  13  adolescent

# %% [markdown]
# ## SUBMITTED RUN 1
#
# Baseline query with MeSH age groups and grid-search optimized parameters.
# Relevance: 3

# %% [markdown]
# Evaluate on 2017 topics and qrels first.

# %%
run_params = {
    'run_id':'imi_mug_abs1',
    'query_template':'submitted/imi_mug_abs1.json',
}

run, run_params = running.run(topics_2017, 'ABSTRACTS', run_params)
results, aggregated = evaluation.evaluate(qrels_2017, run)

aggregated
# Out:
# RUN: imi_mug_abs1 TOPICS: 30
# {'recall_1000': 0.6187, 'ndcg': 0.544, 'Rprec': 0.2817, 'P_10': 0.52}

# %% [markdown]
# Run on 2018 topics and export to file for submission

# %%
run, run_params = running.run(topics_2018, 'ABSTRACTS', run_params)
run
# Out:
# RUN: imi_mug_abs1 TOPICS: 50
#        TOPIC_NO  Q0             ID  RANK      SCORE      RUN_NAME  \
# 0             1  Q0       23403819     1  59.769985  imi_mug_abs1
# 1             1  Q0       22535154     2  57.334800  imi_mug_abs1
# 2             1  Q0       25442222     3  57.010956  imi_mug_abs1
# 3             1  Q0       24535907     4  56.488800  imi_mug_abs1
# 4             1  Q0       22189819     5  55.627040  imi_mug_abs1
# 5             1  Q0       25607474     6  55.254140  imi_mug_abs1
# 6             1  Q0       26924424     7  55.209420  imi_mug_abs1
# 7             1  Q0       25117819     8  54.907185  imi_mug_abs1
# 8             1  Q0       23802768     9  54.520744  imi_mug_abs1
# 9             1  Q0       23026937    10  54.440190  imi_mug_abs1
# 10            1  Q0       17409425    11  54.256554  imi_mug_abs1
# 11            1  Q0       23174497    12  54.221653  imi_mug_abs1
# 12            1  Q0       22850568    13  54.063667  imi_mug_abs1
# 13            1  Q0       25960652    14  54.057228  imi_mug_abs1
# 14            1  Q0       25848750    15  54.000286  imi_mug_abs1
# 15            1  Q0       26138035    16  53.978065  imi_mug_abs1
# 16            1  Q0       26451873    17  53.877663  imi_mug_abs1
# 17            1  Q0       24471189    18  53.631645  imi_mug_abs1
# 18            1  Q0       25543407    19  53.457510  imi_mug_abs1
# 19            1  Q0       16410717    20  53.434017  imi_mug_abs1
# 20            1  Q0       25472943    21  53.369976  imi_mug_abs1
# 21            1  Q0       26600396    22  53.286465  imi_mug_abs1
# 22            1  Q0       26058727    23  52.965652  imi_mug_abs1
# 23            1  Q0       27793752    24  52.845030  imi_mug_abs1
# 24            1  Q0       24684646    25  52.783610  imi_mug_abs1
# 25            1  Q0       24023633    26  52.711224  imi_mug_abs1
# 26            1  Q0       26790143    27  52.412697  imi_mug_abs1
# 27            1  Q0       25257244    28  52.030160  imi_mug_abs1
# 28            1  Q0       19282848    29  51.949300  imi_mug_abs1
# 29            1  Q0       27320919    30  51.932663  imi_mug_abs1
# ...         ...  ..            ...   ...        ...           ...
# 41249        50  Q0       18273044   971  43.450634  imi_mug_abs1
# 41250        50  Q0       17577018   972  43.445835  imi_mug_abs1
# 41251        50  Q0       25956709   973  43.417027  imi_mug_abs1
# 41252        50  Q0       14977832   974  43.408974  imi_mug_abs1
# 41253        50  Q0       23929217   975  43.401634  imi_mug_abs1
# 41254        50  Q0       20111072   976  43.400955  imi_mug_abs1
# 41255        50  Q0       25379410   977  43.393528  imi_mug_abs1
# 41256        50  Q0       12070009   978  43.364790  imi_mug_abs1
# 41257        50  Q0       21504297   979  43.360905  imi_mug_abs1
# 41258        50  Q0       23740774   980  43.356586  imi_mug_abs1
# 41259        50  Q0       15257941   981  43.355648  imi_mug_abs1
# 41260        50  Q0       22844482   982  43.349594  imi_mug_abs1
# 41261        50  Q0       27315441   983  43.336716  imi_mug_abs1
# 41262        50  Q0       27346558   984  43.330315  imi_mug_abs1
# 41263        50  Q0       20439648   985  43.326400  imi_mug_abs1
# 41264        50  Q0       18184863   986  43.296253  imi_mug_abs1
# 41265        50  Q0       10720129   987  43.294930  imi_mug_abs1
# 41266        50  Q0       12842996   988  43.291000  imi_mug_abs1
# 41267        50  Q0       23632886   989  43.290290  imi_mug_abs1
# 41268        50  Q0       25111583   990  43.287964  imi_mug_abs1
# 41269        50  Q0       23907410   991  43.287090  imi_mug_abs1
# 41270        50  Q0  ASCO_50851-74   992  43.257960  imi_mug_abs1
# 41271        50  Q0       24002496   993  43.257084  imi_mug_abs1
# 41272        50  Q0       27014976   994  43.246130  imi_mug_abs1
# 41273        50  Q0       14504097   995  43.244495  imi_mug_abs1
# 41274        50  Q0       20148885   996  43.218834  imi_mug_abs1
# 41275        50  Q0       19176014   997  43.210754  imi_mug_abs1
# 41276        50  Q0       25443887   998  43.209510  imi_mug_abs1
# 41277        50  Q0       23300935   999  43.204727  imi_mug_abs1
# 41278        50  Q0       21859732  1000  43.181640  imi_mug_abs1
#
#                                                    TITLE
# 0      BRAF(V600E) protein expression and outcome fro...
# 1      Distinguishing clinicopathologic features of p...
# 2      Prospective immunohistochemical analysis of BR...
# 3      Analysis of the BRAF V600E mutation in primary...
# 4      The BRAF(V600E) causes widespread alterations ...
# 5      BRAF wild-type melanoma in situ arising in a B...
# 6      BRAF-V600E expression in primary nodular melan...
# 7      BRAF(V600E) melanoma cells secrete factors tha...
# 8      Impact of MET expression on outcome in BRAF(V6...
# 9      Immunohistochemistry is highly sensitive and s...
# 10     Mutant V600E BRAF increases hypoxia inducible ...
# 11     Molecular platforms utilized to detect BRAF V6...
# 12     Oncogenic BRAF(V600E) promotes stromal cell-me...
# 13     Insight into molecular dynamics simulation of ...
# 14     Transposon mutagenesis identifies genetic driv...
# 15     Pathogenetic Implications of BRAF Mutation Dis...
# 16     Type I-polarized BRAF-pulsed dendritic cells i...
# 17     Clinicopathologic findings and BRAF mutation i...
# 18     [BRAF V600E mutation detection in melanoma pat...
# 19     Detection of BRAF gene mutation in primary cho...
# 20     PI3'-kinase inhibition forestalls the onset of...
# 21     The \\textit{BRAF} V600E mutation in single- i...
# 22     Utility of BRAF V600E Immunohistochemistry Exp...
# 23     Targeting CPT1A enhances metabolic therapy in ...
# 24     Expression of AID in malignant melanoma with B...
# 25     Differential inhibition of ex-vivo tumor kinas...
# 26     p53 Reactivation by PRIMA-1(Met) (APR-246) sen...
# 27     Diffuse melanosis cutis in the setting of BRAF...
# 28     Braf(V600E) cooperates with Pten loss to induc...
# 29     BRAF(V600E) Kinase Domain Duplication Identifi...
# ...                                                  ...
# 41249  NPM1 mutations in therapy-related acute myeloi...
# 41250  High expression levels of the ETS-related gene...
# 41251  Direct and indirect targeting of MYC to treat ...
# 41252  Heterogeneous patterns of FLT3 Asp(835) mutati...
# 41253  Integration of cytogenetic and molecular alter...
# 41254  FES kinases are required for oncogenic FLT3 si...
# 41255  Deletion and deletion\/insertion mutations in ...
# 41256  Analysis of FLT3 length mutations in 1003 pati...
# 41257  Molecular analysis of WT1 and KIT mutations in...
# 41258  Increased coexpression of c-KIT and FLT3 recep...
# 41259  NRAS, FLT3 and TP53 mutations in patients with...
# 41260  Acute myeloid leukemia (AML) with erythroid pr...
# 41261  Does FLT3 mutation impact survival after hemat...
# 41262  The new and recurrent FLT3 juxtamembrane delet...
# 41263  Prognostic significance of CEBPA mutations in ...
# 41264  Potentiation of antileukemic therapies by the ...
# 41265  In vivo treatment of mutant FLT3-transformed m...
# 41266  Different antiapoptotic pathways between wild-...
# 41267  Clinical impact of DNMT3A mutations in younger...
# 41268  Synergistic cytotoxicity of sorafenib with bus...
# 41269  A fast and simple approach for the simultaneou...
# 41270  Race and overall survival in acute myeloid leu...
# 41271  Phase I study of quizartinib administered dail...
# 41272  [Long-term outcomes of homoharringtonine, cyta...
# 41273  FLT3 mutations in the activation loop of tyros...
# 41274  The genotype nucleophosmin mutated and FLT3-IT...
# 41275  [Prevalence and clinical significance of FLT3 ...
# 41276  Prognosis of body mass index and chemotherapy ...
# 41277  Src-Like adaptor protein (SLAP) binds to the r...
# 41278  Clinical impact of FLT3 mutation load in acute...
#
# [41279 rows x 7 columns]

# %%
utils.to_trec_run_file(run, run_params)

# %% [markdown]
# ## SUBMITTED RUN 2
#
# Baseline query with MeSH age groups and grid-search optimized parameters. Boost English and extra topics.
# Relevance: 2

# %% [markdown]
# Evaluate on 2017 topics and qrels first.

# %%
run_params = {
    'run_id':'imi_mug_abs2',
    'query_template':'submitted/imi_mug_abs2.json',
}

run, run_params = running.run(topics_2017, 'ABSTRACTS', run_params)
results, aggregated = evaluation.evaluate(qrels_2017, run)

aggregated
# Out:
# RUN: imi_mug_abs2 TOPICS: 30
# {'recall_1000': 0.6188, 'ndcg': 0.545, 'Rprec': 0.2823, 'P_10': 0.5233}

# %% [markdown]
# Run on 2018 topics and export to file for submission

# %%
run, run_params = running.run(topics_2018, 'ABSTRACTS', run_params)
run
# Out:
# RUN: imi_mug_abs2 TOPICS: 50
#        TOPIC_NO  Q0              ID  RANK      SCORE      RUN_NAME  \
# 0             1  Q0        23403819     1  59.769985  imi_mug_abs2
# 1             1  Q0        22535154     2  57.334800  imi_mug_abs2
# 2             1  Q0        25442222     3  57.010956  imi_mug_abs2
# 3             1  Q0        24535907     4  56.488800  imi_mug_abs2
# 4             1  Q0        22189819     5  55.627040  imi_mug_abs2
# 5             1  Q0        25607474     6  55.254140  imi_mug_abs2
# 6             1  Q0        26924424     7  55.209420  imi_mug_abs2
# 7             1  Q0        25117819     8  54.907185  imi_mug_abs2
# 8             1  Q0        23802768     9  54.520744  imi_mug_abs2
# 9             1  Q0        23026937    10  54.440190  imi_mug_abs2
# 10            1  Q0        17409425    11  54.256554  imi_mug_abs2
# 11            1  Q0        23174497    12  54.221653  imi_mug_abs2
# 12            1  Q0        22850568    13  54.063667  imi_mug_abs2
# 13            1  Q0        25960652    14  54.057228  imi_mug_abs2
# 14            1  Q0        25848750    15  54.000286  imi_mug_abs2
# 15            1  Q0        26138035    16  53.978065  imi_mug_abs2
# 16            1  Q0        26451873    17  53.877663  imi_mug_abs2
# 17            1  Q0        24471189    18  53.631645  imi_mug_abs2
# 18            1  Q0        25543407    19  53.457510  imi_mug_abs2
# 19            1  Q0        16410717    20  53.434017  imi_mug_abs2
# 20            1  Q0        25472943    21  53.369976  imi_mug_abs2
# 21            1  Q0        26600396    22  53.286465  imi_mug_abs2
# 22            1  Q0        26058727    23  52.965652  imi_mug_abs2
# 23            1  Q0        27793752    24  52.845030  imi_mug_abs2
# 24            1  Q0        24684646    25  52.783610  imi_mug_abs2
# 25            1  Q0        24023633    26  52.711224  imi_mug_abs2
# 26            1  Q0  AACR_2016-1138    27  52.506264  imi_mug_abs2
# 27            1  Q0        26790143    28  52.412697  imi_mug_abs2
# 28            1  Q0        25257244    29  52.030160  imi_mug_abs2
# 29            1  Q0        19282848    30  51.949300  imi_mug_abs2
# ...         ...  ..             ...   ...        ...           ...
# 41249        50  Q0        23816818   971  43.482376  imi_mug_abs2
# 41250        50  Q0        17537993   972  43.472824  imi_mug_abs2
# 41251        50  Q0        18187662   973  43.450855  imi_mug_abs2
# 41252        50  Q0        18273044   974  43.450634  imi_mug_abs2
# 41253        50  Q0        17577018   975  43.445835  imi_mug_abs2
# 41254        50  Q0        25956709   976  43.417027  imi_mug_abs2
# 41255        50  Q0        14977832   977  43.408974  imi_mug_abs2
# 41256        50  Q0        23929217   978  43.401634  imi_mug_abs2
# 41257        50  Q0        20111072   979  43.400955  imi_mug_abs2
# 41258        50  Q0        25379410   980  43.393528  imi_mug_abs2
# 41259        50  Q0        12070009   981  43.364790  imi_mug_abs2
# 41260        50  Q0        21504297   982  43.360905  imi_mug_abs2
# 41261        50  Q0        23740774   983  43.356586  imi_mug_abs2
# 41262        50  Q0        15257941   984  43.355648  imi_mug_abs2
# 41263        50  Q0        22844482   985  43.349594  imi_mug_abs2
# 41264        50  Q0        27315441   986  43.336716  imi_mug_abs2
# 41265        50  Q0        27346558   987  43.330315  imi_mug_abs2
# 41266        50  Q0        20439648   988  43.326400  imi_mug_abs2
# 41267        50  Q0        18184863   989  43.296253  imi_mug_abs2
# 41268        50  Q0        10720129   990  43.294930  imi_mug_abs2
# 41269        50  Q0        12842996   991  43.291000  imi_mug_abs2
# 41270        50  Q0        23632886   992  43.290290  imi_mug_abs2
# 41271        50  Q0        25111583   993  43.287964  imi_mug_abs2
# 41272        50  Q0        23907410   994  43.287090  imi_mug_abs2
# 41273        50  Q0  AACR_2015-2631   995  43.276382  imi_mug_abs2
# 41274        50  Q0        24002496   996  43.257084  imi_mug_abs2
# 41275        50  Q0        27014976   997  43.246130  imi_mug_abs2
# 41276        50  Q0        14504097   998  43.244495  imi_mug_abs2
# 41277        50  Q0        20148885   999  43.218834  imi_mug_abs2
# 41278        50  Q0        19176014  1000  43.210754  imi_mug_abs2
#
#                                                    TITLE
# 0      BRAF(V600E) protein expression and outcome fro...
# 1      Distinguishing clinicopathologic features of p...
# 2      Prospective immunohistochemical analysis of BR...
# 3      Analysis of the BRAF V600E mutation in primary...
# 4      The BRAF(V600E) causes widespread alterations ...
# 5      BRAF wild-type melanoma in situ arising in a B...
# 6      BRAF-V600E expression in primary nodular melan...
# 7      BRAF(V600E) melanoma cells secrete factors tha...
# 8      Impact of MET expression on outcome in BRAF(V6...
# 9      Immunohistochemistry is highly sensitive and s...
# 10     Mutant V600E BRAF increases hypoxia inducible ...
# 11     Molecular platforms utilized to detect BRAF V6...
# 12     Oncogenic BRAF(V600E) promotes stromal cell-me...
# 13     Insight into molecular dynamics simulation of ...
# 14     Transposon mutagenesis identifies genetic driv...
# 15     Pathogenetic Implications of BRAF Mutation Dis...
# 16     Type I-polarized BRAF-pulsed dendritic cells i...
# 17     Clinicopathologic findings and BRAF mutation i...
# 18     [BRAF V600E mutation detection in melanoma pat...
# 19     Detection of BRAF gene mutation in primary cho...
# 20     PI3'-kinase inhibition forestalls the onset of...
# 21     The \\textit{BRAF} V600E mutation in single- i...
# 22     Utility of BRAF V600E Immunohistochemistry Exp...
# 23     Targeting CPT1A enhances metabolic therapy in ...
# 24     Expression of AID in malignant melanoma with B...
# 25     Differential inhibition of ex-vivo tumor kinas...
# 26     Prognostic impact of BRAF-V600E expression and...
# 27     p53 Reactivation by PRIMA-1(Met) (APR-246) sen...
# 28     Diffuse melanosis cutis in the setting of BRAF...
# 29     Braf(V600E) cooperates with Pten loss to induc...
# ...                                                  ...
# 41249  Acute promyelocytic leukemia with Flt3-TKD and...
# 41250  Pharmacologic inhibition of CDK4\/6: mechanist...
# 41251  MicroRNA signatures associated with cytogeneti...
# 41252  NPM1 mutations in therapy-related acute myeloi...
# 41253  High expression levels of the ETS-related gene...
# 41254  Direct and indirect targeting of MYC to treat ...
# 41255  Heterogeneous patterns of FLT3 Asp(835) mutati...
# 41256  Integration of cytogenetic and molecular alter...
# 41257  FES kinases are required for oncogenic FLT3 si...
# 41258  Deletion and deletion\/insertion mutations in ...
# 41259  Analysis of FLT3 length mutations in 1003 pati...
# 41260  Molecular analysis of WT1 and KIT mutations in...
# 41261  Increased coexpression of c-KIT and FLT3 recep...
# 41262  NRAS, FLT3 and TP53 mutations in patients with...
# 41263  Acute myeloid leukemia (AML) with erythroid pr...
# 41264  Does FLT3 mutation impact survival after hemat...
# 41265  The new and recurrent FLT3 juxtamembrane delet...
# 41266  Prognostic significance of CEBPA mutations in ...
# 41267  Potentiation of antileukemic therapies by the ...
# 41268  In vivo treatment of mutant FLT3-transformed m...
# 41269  Different antiapoptotic pathways between wild-...
# 41270  Clinical impact of DNMT3A mutations in younger...
# 41271  Synergistic cytotoxicity of sorafenib with bus...
# 41272  A fast and simple approach for the simultaneou...
# 41273  Discovery of SC110237, a highly potent, select...
# 41274  Phase I study of quizartinib administered dail...
# 41275  [Long-term outcomes of homoharringtonine, cyta...
# 41276  FLT3 mutations in the activation loop of tyros...
# 41277  The genotype nucleophosmin mutated and FLT3-IT...
# 41278  [Prevalence and clinical significance of FLT3 ...
#
# [41279 rows x 7 columns]

# %%
utils.to_trec_run_file(run, run_params)

# %% [markdown]
# ## SUBMITTED RUN 3
#
# Baseline query with MeSH age groups and grid-search optimized parameters. Boost English and extra topics. Search age group and sex in title, abstract, and MeSH.
# Relevance: 4

# %% [markdown]
# Evaluate on 2017 topics and qrels first.

# %%
run_params = {
    'run_id':'imi_mug_abs3',
    'query_template':'submitted/imi_mug_abs3.json',
}

run, run_params = running.run(topics_2017, 'ABSTRACTS', run_params)
results, aggregated = evaluation.evaluate(qrels_2017, run)

aggregated
# Out:
# RUN: imi_mug_abs3 TOPICS: 30
# {'recall_1000': 0.6174, 'ndcg': 0.5442, 'Rprec': 0.2772, 'P_10': 0.51}

# %% [markdown]
# Run on 2018 topics and export to file for submission

# %%
run, run_params = running.run(topics_2018, 'ABSTRACTS', run_params)
run
# Out:
# RUN: imi_mug_abs3 TOPICS: 50
#        TOPIC_NO  Q0              ID  RANK      SCORE      RUN_NAME  \
# 0             1  Q0        23403819     1  59.940440  imi_mug_abs3
# 1             1  Q0        22535154     2  57.503570  imi_mug_abs3
# 2             1  Q0        25442222     3  57.174026  imi_mug_abs3
# 3             1  Q0        24471189     4  57.041164  imi_mug_abs3
# 4             1  Q0        24535907     5  56.657570  imi_mug_abs3
# 5             1  Q0        22189819     6  55.790110  imi_mug_abs3
# 6             1  Q0        25607474     7  55.413105  imi_mug_abs3
# 7             1  Q0        25257244     8  55.376274  imi_mug_abs3
# 8             1  Q0        26924424     9  55.372486  imi_mug_abs3
# 9             1  Q0        25117819    10  55.066150  imi_mug_abs3
# 10            1  Q0        23802768    11  54.689518  imi_mug_abs3
# 11            1  Q0        23026937    12  54.603260  imi_mug_abs3
# 12            1  Q0        17409425    13  54.415520  imi_mug_abs3
# 13            1  Q0        23174497    14  54.380620  imi_mug_abs3
# 14            1  Q0        25960652    15  54.227684  imi_mug_abs3
# 15            1  Q0        22850568    16  54.222633  imi_mug_abs3
# 16            1  Q0        25848750    17  54.163353  imi_mug_abs3
# 17            1  Q0        26138035    18  54.137030  imi_mug_abs3
# 18            1  Q0        26451873    19  54.036630  imi_mug_abs3
# 19            1  Q0        16410717    20  53.604477  imi_mug_abs3
# 20            1  Q0        25472943    21  53.538746  imi_mug_abs3
# 21            1  Q0        27009410    22  53.534447  imi_mug_abs3
# 22            1  Q0        25543407    23  53.457510  imi_mug_abs3
# 23            1  Q0        26600396    24  53.456920  imi_mug_abs3
# 24            1  Q0        26058727    25  53.125420  imi_mug_abs3
# 25            1  Q0        27793752    26  53.008102  imi_mug_abs3
# 26            1  Q0        24684646    27  52.954067  imi_mug_abs3
# 27            1  Q0        24023633    28  52.874290  imi_mug_abs3
# 28            1  Q0        26790143    29  52.583153  imi_mug_abs3
# 29            1  Q0  AACR_2016-1138    30  52.506264  imi_mug_abs3
# ...         ...  ..             ...   ...        ...           ...
# 41249        50  Q0        25530214   971  43.666256  imi_mug_abs3
# 41250        50  Q0        23816818   972  43.645447  imi_mug_abs3
# 41251        50  Q0        25145343   973  43.643750  imi_mug_abs3
# 41252        50  Q0        17537993   974  43.643280  imi_mug_abs3
# 41253        50  Q0        18187662   975  43.619625  imi_mug_abs3
# 41254        50  Q0        17577018   976  43.614610  imi_mug_abs3
# 41255        50  Q0        18273044   977  43.613705  imi_mug_abs3
# 41256        50  Q0        26458431   978  43.576860  imi_mug_abs3
# 41257        50  Q0        25956709   979  43.576794  imi_mug_abs3
# 41258        50  Q0        23929217   980  43.570404  imi_mug_abs3
# 41259        50  Q0        14977832   981  43.567940  imi_mug_abs3
# 41260        50  Q0        25379410   982  43.562298  imi_mug_abs3
# 41261        50  Q0        20111072   983  43.560722  imi_mug_abs3
# 41262        50  Q0        21504297   984  43.523975  imi_mug_abs3
# 41263        50  Q0        12070009   985  43.523758  imi_mug_abs3
# 41264        50  Q0        22844482   986  43.520050  imi_mug_abs3
# 41265        50  Q0        15257941   987  43.518720  imi_mug_abs3
# 41266        50  Q0        23740774   988  43.515553  imi_mug_abs3
# 41267        50  Q0        20439648   989  43.496857  imi_mug_abs3
# 41268        50  Q0        27315441   990  43.496483  imi_mug_abs3
# 41269        50  Q0        27346558   991  43.493385  imi_mug_abs3
# 41270        50  Q0        18184863   992  43.459324  imi_mug_abs3
# 41271        50  Q0        12842996   993  43.454070  imi_mug_abs3
# 41272        50  Q0        10720129   994  43.453896  imi_mug_abs3
# 41273        50  Q0        23632886   995  43.453360  imi_mug_abs3
# 41274        50  Q0        25111583   996  43.446930  imi_mug_abs3
# 41275        50  Q0        23907410   997  43.446857  imi_mug_abs3
# 41276        50  Q0        24002496   998  43.427540  imi_mug_abs3
# 41277        50  Q0        14504097   999  43.413265  imi_mug_abs3
# 41278        50  Q0        20148885  1000  43.387604  imi_mug_abs3
#
#                                                    TITLE
# 0      BRAF(V600E) protein expression and outcome fro...
# 1      Distinguishing clinicopathologic features of p...
# 2      Prospective immunohistochemical analysis of BR...
# 3      Clinicopathologic findings and BRAF mutation i...
# 4      Analysis of the BRAF V600E mutation in primary...
# 5      The BRAF(V600E) causes widespread alterations ...
# 6      BRAF wild-type melanoma in situ arising in a B...
# 7      Diffuse melanosis cutis in the setting of BRAF...
# 8      BRAF-V600E expression in primary nodular melan...
# 9      BRAF(V600E) melanoma cells secrete factors tha...
# 10     Impact of MET expression on outcome in BRAF(V6...
# 11     Immunohistochemistry is highly sensitive and s...
# 12     Mutant V600E BRAF increases hypoxia inducible ...
# 13     Molecular platforms utilized to detect BRAF V6...
# 14     Insight into molecular dynamics simulation of ...
# 15     Oncogenic BRAF(V600E) promotes stromal cell-me...
# 16     Transposon mutagenesis identifies genetic driv...
# 17     Pathogenetic Implications of BRAF Mutation Dis...
# 18     Type I-polarized BRAF-pulsed dendritic cells i...
# 19     Detection of BRAF gene mutation in primary cho...
# 20     PI3'-kinase inhibition forestalls the onset of...
# 21     BRAF mutations in conjunctival melanoma: inves...
# 22     [BRAF V600E mutation detection in melanoma pat...
# 23     The \\textit{BRAF} V600E mutation in single- i...
# 24     Utility of BRAF V600E Immunohistochemistry Exp...
# 25     Targeting CPT1A enhances metabolic therapy in ...
# 26     Expression of AID in malignant melanoma with B...
# 27     Differential inhibition of ex-vivo tumor kinas...
# 28     p53 Reactivation by PRIMA-1(Met) (APR-246) sen...
# 29     Prognostic impact of BRAF-V600E expression and...
# ...                                                  ...
# 41249  Phase I\/II trial of the combination of midost...
# 41250  Acute promyelocytic leukemia with Flt3-TKD and...
# 41251  NUP98\/NSD1 and FLT3\/ITD coexpression is more...
# 41252  Pharmacologic inhibition of CDK4\/6: mechanist...
# 41253  MicroRNA signatures associated with cytogeneti...
# 41254  High expression levels of the ETS-related gene...
# 41255  NPM1 mutations in therapy-related acute myeloi...
# 41256  [AML treatment strategy based on cytogenetic a...
# 41257  Direct and indirect targeting of MYC to treat ...
# 41258  Integration of cytogenetic and molecular alter...
# 41259  Heterogeneous patterns of FLT3 Asp(835) mutati...
# 41260  Deletion and deletion\/insertion mutations in ...
# 41261  FES kinases are required for oncogenic FLT3 si...
# 41262  Molecular analysis of WT1 and KIT mutations in...
# 41263  Analysis of FLT3 length mutations in 1003 pati...
# 41264  Acute myeloid leukemia (AML) with erythroid pr...
# 41265  NRAS, FLT3 and TP53 mutations in patients with...
# 41266  Increased coexpression of c-KIT and FLT3 recep...
# 41267  Prognostic significance of CEBPA mutations in ...
# 41268  Does FLT3 mutation impact survival after hemat...
# 41269  The new and recurrent FLT3 juxtamembrane delet...
# 41270  Potentiation of antileukemic therapies by the ...
# 41271  Different antiapoptotic pathways between wild-...
# 41272  In vivo treatment of mutant FLT3-transformed m...
# 41273  Clinical impact of DNMT3A mutations in younger...
# 41274  Synergistic cytotoxicity of sorafenib with bus...
# 41275  A fast and simple approach for the simultaneou...
# 41276  Phase I study of quizartinib administered dail...
# 41277  FLT3 mutations in the activation loop of tyros...
# 41278  The genotype nucleophosmin mutated and FLT3-IT...
#
# [41279 rows x 7 columns]

# %%
utils.to_trec_run_file(run, run_params)

# %% [markdown]
# ## SUBMITTED RUN 4
#
# Baseline query with MeSH age groups and grid-search optimized parameters. Boost English and extra topics. Search age group and sex in title, abstract, and MeSH. Abstract should exist.
# Relevance: 5

# %% [markdown]
# Evaluate on 2017 topics and qrels first.

# %%
run_params = {
    'run_id':'imi_mug_abs4',
    'query_template':'submitted/imi_mug_abs4.json',
}

run, run_params = running.run(topics_2017, 'ABSTRACTS', run_params)
results, aggregated = evaluation.evaluate(qrels_2017, run)

aggregated
# Out:
# RUN: imi_mug_abs4 TOPICS: 30
# {'recall_1000': 0.6143, 'ndcg': 0.5424, 'Rprec': 0.2772, 'P_10': 0.51}

# %% [markdown]
# Run on 2018 topics and export to file for submission

# %%
run, run_params = running.run(topics_2018, 'ABSTRACTS', run_params)
run
# Out:
# RUN: imi_mug_abs4 TOPICS: 50
#        TOPIC_NO  Q0              ID  RANK      SCORE      RUN_NAME  \
# 0             1  Q0        23403819     1  59.940440  imi_mug_abs4
# 1             1  Q0        22535154     2  57.503570  imi_mug_abs4
# 2             1  Q0        25442222     3  57.174026  imi_mug_abs4
# 3             1  Q0        24471189     4  57.041164  imi_mug_abs4
# 4             1  Q0        24535907     5  56.657570  imi_mug_abs4
# 5             1  Q0        22189819     6  55.790110  imi_mug_abs4
# 6             1  Q0        25607474     7  55.413105  imi_mug_abs4
# 7             1  Q0        25257244     8  55.376274  imi_mug_abs4
# 8             1  Q0        26924424     9  55.372486  imi_mug_abs4
# 9             1  Q0        25117819    10  55.066150  imi_mug_abs4
# 10            1  Q0        23802768    11  54.689518  imi_mug_abs4
# 11            1  Q0        23026937    12  54.603260  imi_mug_abs4
# 12            1  Q0        17409425    13  54.415520  imi_mug_abs4
# 13            1  Q0        23174497    14  54.380620  imi_mug_abs4
# 14            1  Q0        25960652    15  54.227684  imi_mug_abs4
# 15            1  Q0        22850568    16  54.222633  imi_mug_abs4
# 16            1  Q0        25848750    17  54.163353  imi_mug_abs4
# 17            1  Q0        26138035    18  54.137030  imi_mug_abs4
# 18            1  Q0        26451873    19  54.036630  imi_mug_abs4
# 19            1  Q0        16410717    20  53.604477  imi_mug_abs4
# 20            1  Q0        25472943    21  53.538746  imi_mug_abs4
# 21            1  Q0        27009410    22  53.534447  imi_mug_abs4
# 22            1  Q0        25543407    23  53.457510  imi_mug_abs4
# 23            1  Q0        26600396    24  53.456920  imi_mug_abs4
# 24            1  Q0        26058727    25  53.125420  imi_mug_abs4
# 25            1  Q0        27793752    26  53.008102  imi_mug_abs4
# 26            1  Q0        24684646    27  52.954067  imi_mug_abs4
# 27            1  Q0        24023633    28  52.874290  imi_mug_abs4
# 28            1  Q0        26790143    29  52.583153  imi_mug_abs4
# 29            1  Q0  AACR_2016-1138    30  52.506264  imi_mug_abs4
# ...         ...  ..             ...   ...        ...           ...
# 40992        50  Q0        25145343   971  43.643750  imi_mug_abs4
# 40993        50  Q0        17537993   972  43.643280  imi_mug_abs4
# 40994        50  Q0        18187662   973  43.619625  imi_mug_abs4
# 40995        50  Q0        17577018   974  43.614610  imi_mug_abs4
# 40996        50  Q0        18273044   975  43.613705  imi_mug_abs4
# 40997        50  Q0        26458431   976  43.576860  imi_mug_abs4
# 40998        50  Q0        25956709   977  43.576794  imi_mug_abs4
# 40999        50  Q0        23929217   978  43.570404  imi_mug_abs4
# 41000        50  Q0        14977832   979  43.567940  imi_mug_abs4
# 41001        50  Q0        25379410   980  43.562298  imi_mug_abs4
# 41002        50  Q0        20111072   981  43.560722  imi_mug_abs4
# 41003        50  Q0        21504297   982  43.523975  imi_mug_abs4
# 41004        50  Q0        12070009   983  43.523758  imi_mug_abs4
# 41005        50  Q0        22844482   984  43.520050  imi_mug_abs4
# 41006        50  Q0        15257941   985  43.518720  imi_mug_abs4
# 41007        50  Q0        23740774   986  43.515553  imi_mug_abs4
# 41008        50  Q0        20439648   987  43.496857  imi_mug_abs4
# 41009        50  Q0        27315441   988  43.496483  imi_mug_abs4
# 41010        50  Q0        27346558   989  43.493385  imi_mug_abs4
# 41011        50  Q0        18184863   990  43.459324  imi_mug_abs4
# 41012        50  Q0        12842996   991  43.454070  imi_mug_abs4
# 41013        50  Q0        10720129   992  43.453896  imi_mug_abs4
# 41014        50  Q0        23632886   993  43.453360  imi_mug_abs4
# 41015        50  Q0        25111583   994  43.446930  imi_mug_abs4
# 41016        50  Q0        23907410   995  43.446857  imi_mug_abs4
# 41017        50  Q0        24002496   996  43.427540  imi_mug_abs4
# 41018        50  Q0        14504097   997  43.413265  imi_mug_abs4
# 41019        50  Q0        20148885   998  43.387604  imi_mug_abs4
# 41020        50  Q0        25443887   999  43.378280  imi_mug_abs4
# 41021        50  Q0        23300935  1000  43.375183  imi_mug_abs4
#
#                                                    TITLE
# 0      BRAF(V600E) protein expression and outcome fro...
# 1      Distinguishing clinicopathologic features of p...
# 2      Prospective immunohistochemical analysis of BR...
# 3      Clinicopathologic findings and BRAF mutation i...
# 4      Analysis of the BRAF V600E mutation in primary...
# 5      The BRAF(V600E) causes widespread alterations ...
# 6      BRAF wild-type melanoma in situ arising in a B...
# 7      Diffuse melanosis cutis in the setting of BRAF...
# 8      BRAF-V600E expression in primary nodular melan...
# 9      BRAF(V600E) melanoma cells secrete factors tha...
# 10     Impact of MET expression on outcome in BRAF(V6...
# 11     Immunohistochemistry is highly sensitive and s...
# 12     Mutant V600E BRAF increases hypoxia inducible ...
# 13     Molecular platforms utilized to detect BRAF V6...
# 14     Insight into molecular dynamics simulation of ...
# 15     Oncogenic BRAF(V600E) promotes stromal cell-me...
# 16     Transposon mutagenesis identifies genetic driv...
# 17     Pathogenetic Implications of BRAF Mutation Dis...
# 18     Type I-polarized BRAF-pulsed dendritic cells i...
# 19     Detection of BRAF gene mutation in primary cho...
# 20     PI3'-kinase inhibition forestalls the onset of...
# 21     BRAF mutations in conjunctival melanoma: inves...
# 22     [BRAF V600E mutation detection in melanoma pat...
# 23     The \\textit{BRAF} V600E mutation in single- i...
# 24     Utility of BRAF V600E Immunohistochemistry Exp...
# 25     Targeting CPT1A enhances metabolic therapy in ...
# 26     Expression of AID in malignant melanoma with B...
# 27     Differential inhibition of ex-vivo tumor kinas...
# 28     p53 Reactivation by PRIMA-1(Met) (APR-246) sen...
# 29     Prognostic impact of BRAF-V600E expression and...
# ...                                                  ...
# 40992  NUP98\/NSD1 and FLT3\/ITD coexpression is more...
# 40993  Pharmacologic inhibition of CDK4\/6: mechanist...
# 40994  MicroRNA signatures associated with cytogeneti...
# 40995  High expression levels of the ETS-related gene...
# 40996  NPM1 mutations in therapy-related acute myeloi...
# 40997  [AML treatment strategy based on cytogenetic a...
# 40998  Direct and indirect targeting of MYC to treat ...
# 40999  Integration of cytogenetic and molecular alter...
# 41000  Heterogeneous patterns of FLT3 Asp(835) mutati...
# 41001  Deletion and deletion\/insertion mutations in ...
# 41002  FES kinases are required for oncogenic FLT3 si...
# 41003  Molecular analysis of WT1 and KIT mutations in...
# 41004  Analysis of FLT3 length mutations in 1003 pati...
# 41005  Acute myeloid leukemia (AML) with erythroid pr...
# 41006  NRAS, FLT3 and TP53 mutations in patients with...
# 41007  Increased coexpression of c-KIT and FLT3 recep...
# 41008  Prognostic significance of CEBPA mutations in ...
# 41009  Does FLT3 mutation impact survival after hemat...
# 41010  The new and recurrent FLT3 juxtamembrane delet...
# 41011  Potentiation of antileukemic therapies by the ...
# 41012  Different antiapoptotic pathways between wild-...
# 41013  In vivo treatment of mutant FLT3-transformed m...
# 41014  Clinical impact of DNMT3A mutations in younger...
# 41015  Synergistic cytotoxicity of sorafenib with bus...
# 41016  A fast and simple approach for the simultaneou...
# 41017  Phase I study of quizartinib administered dail...
# 41018  FLT3 mutations in the activation loop of tyros...
# 41019  The genotype nucleophosmin mutated and FLT3-IT...
# 41020  Prognosis of body mass index and chemotherapy ...
# 41021  Src-Like adaptor protein (SLAP) binds to the r...
#
# [41022 rows x 7 columns]

# %%
utils.to_trec_run_file(run, run_params)

# %% [markdown]
# ## SUBMITTED RUN 5
#
# Baseline query with MeSH age groups and grid-search optimized parameters. Boost English and extra topics. Abstract should exist.
# Relevance: 1

# %% [markdown]
# Evaluate on 2017 topics and qrels first.

# %%
run_params = {
    'run_id':'imi_mug_abs5',
    'query_template':'submitted/imi_mug_abs5.json',
}

run, run_params = running.run(topics_2017, 'ABSTRACTS', run_params)
results, aggregated = evaluation.evaluate(qrels_2017, run)

aggregated
# Out:
# RUN: imi_mug_abs5 TOPICS: 30
# {'recall_1000': 0.6161, 'ndcg': 0.5434, 'Rprec': 0.2824, 'P_10': 0.52}

# %% [markdown]
# Run on 2018 topics and export to file for submission

# %%
run, run_params = running.run(topics_2018, 'ABSTRACTS', run_params)
run
# Out:
# RUN: imi_mug_abs5 TOPICS: 50
#        TOPIC_NO  Q0               ID  RANK      SCORE      RUN_NAME  \
# 0             1  Q0         23403819     1  59.940440  imi_mug_abs5
# 1             1  Q0         22535154     2  57.503570  imi_mug_abs5
# 2             1  Q0         25442222     3  57.174026  imi_mug_abs5
# 3             1  Q0         24535907     4  56.657570  imi_mug_abs5
# 4             1  Q0         22189819     5  55.790110  imi_mug_abs5
# 5             1  Q0         25607474     6  55.413105  imi_mug_abs5
# 6             1  Q0         26924424     7  55.372486  imi_mug_abs5
# 7             1  Q0         25117819     8  55.066150  imi_mug_abs5
# 8             1  Q0         23802768     9  54.689518  imi_mug_abs5
# 9             1  Q0         23026937    10  54.603260  imi_mug_abs5
# 10            1  Q0         17409425    11  54.415520  imi_mug_abs5
# 11            1  Q0         23174497    12  54.380620  imi_mug_abs5
# 12            1  Q0         25960652    13  54.227684  imi_mug_abs5
# 13            1  Q0         22850568    14  54.222633  imi_mug_abs5
# 14            1  Q0         25848750    15  54.163353  imi_mug_abs5
# 15            1  Q0         26138035    16  54.137030  imi_mug_abs5
# 16            1  Q0         26451873    17  54.036630  imi_mug_abs5
# 17            1  Q0         24471189    18  53.790610  imi_mug_abs5
# 18            1  Q0         16410717    19  53.604477  imi_mug_abs5
# 19            1  Q0         25472943    20  53.538746  imi_mug_abs5
# 20            1  Q0         25543407    21  53.457510  imi_mug_abs5
# 21            1  Q0         26600396    22  53.456920  imi_mug_abs5
# 22            1  Q0         26058727    23  53.125420  imi_mug_abs5
# 23            1  Q0         27793752    24  53.008102  imi_mug_abs5
# 24            1  Q0         24684646    25  52.954067  imi_mug_abs5
# 25            1  Q0         24023633    26  52.874290  imi_mug_abs5
# 26            1  Q0         26790143    27  52.583153  imi_mug_abs5
# 27            1  Q0   AACR_2016-1138    28  52.506264  imi_mug_abs5
# 28            1  Q0         25257244    29  52.198930  imi_mug_abs5
# 29            1  Q0         19282848    30  52.108265  imi_mug_abs5
# ...         ...  ..              ...   ...        ...           ...
# 40992        50  Q0         18273044   971  43.613705  imi_mug_abs5
# 40993        50  Q0         26458431   972  43.576860  imi_mug_abs5
# 40994        50  Q0         25956709   973  43.576794  imi_mug_abs5
# 40995        50  Q0         23929217   974  43.570404  imi_mug_abs5
# 40996        50  Q0         14977832   975  43.567940  imi_mug_abs5
# 40997        50  Q0         25379410   976  43.562298  imi_mug_abs5
# 40998        50  Q0         20111072   977  43.560722  imi_mug_abs5
# 40999        50  Q0         21504297   978  43.523975  imi_mug_abs5
# 41000        50  Q0         12070009   979  43.523758  imi_mug_abs5
# 41001        50  Q0         22844482   980  43.520050  imi_mug_abs5
# 41002        50  Q0         15257941   981  43.518720  imi_mug_abs5
# 41003        50  Q0         23740774   982  43.515553  imi_mug_abs5
# 41004        50  Q0  ASCO_150588-156   983  43.514774  imi_mug_abs5
# 41005        50  Q0         20439648   984  43.496857  imi_mug_abs5
# 41006        50  Q0         27315441   985  43.496483  imi_mug_abs5
# 41007        50  Q0         27346558   986  43.493385  imi_mug_abs5
# 41008        50  Q0         18184863   987  43.459324  imi_mug_abs5
# 41009        50  Q0         12842996   988  43.454070  imi_mug_abs5
# 41010        50  Q0         10720129   989  43.453896  imi_mug_abs5
# 41011        50  Q0         23632886   990  43.453360  imi_mug_abs5
# 41012        50  Q0         25111583   991  43.446930  imi_mug_abs5
# 41013        50  Q0         23907410   992  43.446857  imi_mug_abs5
# 41014        50  Q0         24002496   993  43.427540  imi_mug_abs5
# 41015        50  Q0         14504097   994  43.413265  imi_mug_abs5
# 41016        50  Q0         20148885   995  43.387604  imi_mug_abs5
# 41017        50  Q0         25443887   996  43.378280  imi_mug_abs5
# 41018        50  Q0         23300935   997  43.375183  imi_mug_abs5
# 41019        50  Q0         21859732   998  43.341410  imi_mug_abs5
# 41020        50  Q0         19903674   999  43.326324  imi_mug_abs5
# 41021        50  Q0         17983653  1000  43.321583  imi_mug_abs5
#
#                                                    TITLE
# 0      BRAF(V600E) protein expression and outcome fro...
# 1      Distinguishing clinicopathologic features of p...
# 2      Prospective immunohistochemical analysis of BR...
# 3      Analysis of the BRAF V600E mutation in primary...
# 4      The BRAF(V600E) causes widespread alterations ...
# 5      BRAF wild-type melanoma in situ arising in a B...
# 6      BRAF-V600E expression in primary nodular melan...
# 7      BRAF(V600E) melanoma cells secrete factors tha...
# 8      Impact of MET expression on outcome in BRAF(V6...
# 9      Immunohistochemistry is highly sensitive and s...
# 10     Mutant V600E BRAF increases hypoxia inducible ...
# 11     Molecular platforms utilized to detect BRAF V6...
# 12     Insight into molecular dynamics simulation of ...
# 13     Oncogenic BRAF(V600E) promotes stromal cell-me...
# 14     Transposon mutagenesis identifies genetic driv...
# 15     Pathogenetic Implications of BRAF Mutation Dis...
# 16     Type I-polarized BRAF-pulsed dendritic cells i...
# 17     Clinicopathologic findings and BRAF mutation i...
# 18     Detection of BRAF gene mutation in primary cho...
# 19     PI3'-kinase inhibition forestalls the onset of...
# 20     [BRAF V600E mutation detection in melanoma pat...
# 21     The \\textit{BRAF} V600E mutation in single- i...
# 22     Utility of BRAF V600E Immunohistochemistry Exp...
# 23     Targeting CPT1A enhances metabolic therapy in ...
# 24     Expression of AID in malignant melanoma with B...
# 25     Differential inhibition of ex-vivo tumor kinas...
# 26     p53 Reactivation by PRIMA-1(Met) (APR-246) sen...
# 27     Prognostic impact of BRAF-V600E expression and...
# 28     Diffuse melanosis cutis in the setting of BRAF...
# 29     Braf(V600E) cooperates with Pten loss to induc...
# ...                                                  ...
# 40992  NPM1 mutations in therapy-related acute myeloi...
# 40993  [AML treatment strategy based on cytogenetic a...
# 40994  Direct and indirect targeting of MYC to treat ...
# 40995  Integration of cytogenetic and molecular alter...
# 40996  Heterogeneous patterns of FLT3 Asp(835) mutati...
# 40997  Deletion and deletion\/insertion mutations in ...
# 40998  FES kinases are required for oncogenic FLT3 si...
# 40999  Molecular analysis of WT1 and KIT mutations in...
# 41000  Analysis of FLT3 length mutations in 1003 pati...
# 41001  Acute myeloid leukemia (AML) with erythroid pr...
# 41002  NRAS, FLT3 and TP53 mutations in patients with...
# 41003  Increased coexpression of c-KIT and FLT3 recep...
# 41004  Efficacy and safety of an anti-FLT3 antibody (...
# 41005  Prognostic significance of CEBPA mutations in ...
# 41006  Does FLT3 mutation impact survival after hemat...
# 41007  The new and recurrent FLT3 juxtamembrane delet...
# 41008  Potentiation of antileukemic therapies by the ...
# 41009  Different antiapoptotic pathways between wild-...
# 41010  In vivo treatment of mutant FLT3-transformed m...
# 41011  Clinical impact of DNMT3A mutations in younger...
# 41012  Synergistic cytotoxicity of sorafenib with bus...
# 41013  A fast and simple approach for the simultaneou...
# 41014  Phase I study of quizartinib administered dail...
# 41015  FLT3 mutations in the activation loop of tyros...
# 41016  The genotype nucleophosmin mutated and FLT3-IT...
# 41017  Prognosis of body mass index and chemotherapy ...
# 41018  Src-Like adaptor protein (SLAP) binds to the r...
# 41019  Clinical impact of FLT3 mutation load in acute...
# 41020  Additional chromosome abnormalities in patient...
# 41021  Blockade of MEK\/ERK signaling enhances suniti...
#
# [41022 rows x 7 columns]

# %%
utils.to_trec_run_file(run, run_params)
