# %% [markdown]
# # Submission preparation

# %%
import pprint
import json
from json2html import *
from IPython.display import HTML
import pandas

import os, sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from trec_utils import utils, running, evaluation

# %%
config = utils.load_config()

# %%
topics_all = utils.get_topics('./topics/topics2018.xml')
topics_all
# Out:
#     topic                                disease  \
# 1       1                               melanoma
# 2       2                               melanoma
# 3       3                               melanoma
# 4       4                               melanoma
# 5       5                               melanoma
# 6       6                               melanoma
# 7       7                               melanoma
# 8       8                               melanoma
# 9       9                               melanoma
# 10     10                               melanoma
# 11     11                               melanoma
# 12     12                               melanoma
# 13     13                               melanoma
# 14     14                               melanoma
# 15     15                               melanoma
# 16     16                               melanoma
# 17     17                               melanoma
# 18     18                               melanoma
# 19     19                               melanoma
# 20     20                               melanoma
# 21     21                               melanoma
# 22     22                               melanoma
# 23     23                               melanoma
# 24     24                               melanoma
# 25     25                               melanoma
# 26     26                      colorectal cancer
# 27     27            medullary thyroid carcinoma
# 28     28                          neuroblastoma
# 29     29                      esophageal cancer
# 30     30                            lung cancer
# 31     31  head and neck squamous cell carcinoma
# 32     32                               leukemia
# 33     33                         gastric cancer
# 34     34                                sarcoma
# 35     35                          breast cancer
# 36     36                            lung cancer
# 37     37               non-small cell carcinoma
# 38     38                     cholangiocarcinoma
# 39     39         anaplastic large cell lymphoma
# 40     40                          breast cancer
# 41     41            papillary thyroid carcinoma
# 42     42                           glioblastoma
# 43     43                   basal cell carcinoma
# 44     44                                 glioma
# 45     45                         thyroid cancer
# 46     46                            lung cancer
# 47     47                        prostate cancer
# 48     48               adenoid cystic carcinoma
# 49     49                 acute myeloid leukemia
# 50     50                 acute myeloid leukemia
#
#                                                  gene  \
# 1                                        BRAF (V600E)
# 2                                        BRAF (V600K)
# 3                                        BRAF (V600R)
# 4                                        BRAF (K601E)
# 5                 BRAF (V600E), PTEN loss of function
# 6                           BRAF (V600E), NRAS (Q61R)
# 7                                  BRAF amplification
# 8                                         NRAS (Q61R)
# 9                                         NRAS (Q61L)
# 10                                        KIT (L576P)
# 11                     KIT (L576P), KIT amplification
# 12                                        KIT (K642E)
# 13                                        KIT (N822Y)
# 14                                  KIT amplification
# 15                                     NF1 truncation
# 16                                NTRK1 rearrangement
# 17                              TP53 loss of function
# 18  tumor cells with >50% membranous PD-L1 expression
# 19          tumor cells negative for PD-L1 expression
# 20                       high tumor mutational burden
# 21           extensive tumor infiltrating lymphocytes
# 22                  no tumor infiltrating lymphocytes
# 23                              PTEN loss of function
# 24                               APC loss of function
# 25                              high serum LDH levels
# 26                                               NRAS
# 27                                                RET
# 28                                                ALK
# 29                                               EGFR
# 30                                               ROS1
# 31                                             CDKN2A
# 32                                               ABL1
# 33                                               EGFR
# 34                                               MDM2
# 35                                             CDKN2A
# 36                                              ERBB2
# 37                                                MET
# 38                                               IDH1
# 39                                                ALK
# 40                                              ERBB2
# 41                                              NTRK1
# 42                                               CDK6
# 43                                              PTCH1
# 44                                               BRAF
# 45                                               BRAF
# 46                                              FGFR1
# 47                                               PTEN
# 48                                                KIT
# 49                                               IDH1
# 50                                               FLT3
#
#                                                 gene1                   gene2  \
# 1                                        BRAF (V600E)
# 2                                        BRAF (V600K)
# 3                                        BRAF (V600R)
# 4                                        BRAF (K601E)
# 5                                        BRAF (V600E)   PTEN loss of function
# 6                                        BRAF (V600E)             NRAS (Q61R)
# 7                                  BRAF amplification
# 8                                         NRAS (Q61R)
# 9                                         NRAS (Q61L)
# 10                                        KIT (L576P)
# 11                                        KIT (L576P)       KIT amplification
# 12                                        KIT (K642E)
# 13                                        KIT (N822Y)
# 14                                  KIT amplification
# 15                                     NF1 truncation
# 16                                NTRK1 rearrangement
# 17                              TP53 loss of function
# 18  tumor cells with >50% membranous PD-L1 expression
# 19          tumor cells negative for PD-L1 expression
# 20                       high tumor mutational burden
# 21           extensive tumor infiltrating lymphocytes
# 22                  no tumor infiltrating lymphocytes
# 23                              PTEN loss of function
# 24                               APC loss of function
# 25                              high serum LDH levels
# 26                                               NRAS
# 27                                                RET
# 28                                                ALK
# 29                                               EGFR
# 30                                               ROS1
# 31                                             CDKN2A
# 32                                               ABL1
# 33                                               EGFR
# 34                                               MDM2
# 35                                             CDKN2A
# 36                                              ERBB2
# 37                                                MET
# 38                                               IDH1
# 39                                                ALK
# 40                                              ERBB2
# 41                                              NTRK1
# 42                                               CDK6
# 43                                              PTCH1
# 44                                               BRAF
# 45                                               BRAF
# 46                                              FGFR1
# 47                                               PTEN
# 48                                                KIT
# 49                                               IDH1
# 50                                               FLT3
#
#    gene3     sex age   age_group
# 1           male  64        aged
# 2           male  54        aged
# 3           male  80        aged
# 4           male  38       adult
# 5           male  57        aged
# 6           male  67        aged
# 7           male  61        aged
# 8         female  63        aged
# 9         female  34       adult
# 10        female  65        aged
# 11        female  56        aged
# 12        female  62        aged
# 13        female  39       adult
# 14        female  66        aged
# 15          male  70        aged
# 16          male  60        aged
# 17          male  72        aged
# 18        female  48        aged
# 19          male  73        aged
# 20        female  86        aged
# 21          male  49        aged
# 22        female  74        aged
# 23          male  68        aged
# 24          male  47        aged
# 25        female  69        aged
# 26          male  49        aged
# 27        female  45        aged
# 28        female   4       child
# 29          male  67        aged
# 30        female  71        aged
# 31          male  64        aged
# 32        female   4       child
# 33        female  60        aged
# 34        female  78        aged
# 35        female  73        aged
# 36        female  49        aged
# 37          male  68        aged
# 38          male  50        aged
# 39          male  18       adult
# 40        female  56        aged
# 41        female  46        aged
# 42          male  84        aged
# 43        female  56        aged
# 44          male  82        aged
# 45        female  40       adult
# 46          male  57        aged
# 47          male  70        aged
# 48        female  58        aged
# 49          male   1     newborn
# 50          male  13  adolescent

# %% [markdown]
# ## Run 1: Baseline with sex and age
# Note that run name should be 12 characters or less

# %%
run_params = {
    'run_id':'mugctbase1',
    'query_template':'submitted/baseline_sex_age.json',
    'disease_tie_breaker':0.4,
    'disease_multi_match_type':'best_fields',
    'disease_boost':1.5,
    'gene_tie_breaker':0.5,
    'gene_multi_match_type':'cross_fields',
    'gene_boost':1
}

run, run_params = running.run(topics_all, run_params)
# Out:
# RUN: mugctbase1 TOPICS: 50

# %%
pprint.pprint(run_params)
# Out:
# {'disease_boost': 1.5,
#  'disease_multi_match_type': 'best_fields',
#  'disease_tie_breaker': 0.4,
#  'gene_boost': 1,
#  'gene_multi_match_type': 'cross_fields',
#  'gene_tie_breaker': 0.5,
#  'query_template': 'submitted/baseline_sex_age.json',
#  'run_id': 'mugctbase1'}

# %%
run
# Out:
#        TOPIC_NO  Q0             ID  RANK      SCORE    RUN_NAME  \
# 0             1  Q0       23403819     1  62.053770  mugctbase1
# 1             1  Q0       22535154     2  58.834510  mugctbase1
# 2             1  Q0       25442222     3  58.801414  mugctbase1
# 3             1  Q0       24535907     4  58.297300  mugctbase1
# 3      Analysis of the BRAF V600E mutation in primary...
# 4      The BRAF(V600E) causes widespread alterations ...
# 5      BRAF wild-type melanoma in situ arising in a B...
# 6      BRAF-V600E expression in primary nodular melan...
# 7      BRAF(V600E) melanoma cells secrete factors tha...
# 8      Impact of MET expression on outcome in BRAF(V6...
# 9      Molecular platforms utilized to detect BRAF V6...
# 10     Immunohistochemistry is highly sensitive and s...
# 11     Transposon mutagenesis identifies genetic driv...
# 12     Mutant V600E BRAF increases hypoxia inducible ...
# 13     Oncogenic BRAF(V600E) promotes stromal cell-me...
# 14     Insight into molecular dynamics simulation of ...
# 15     [BRAF V600E mutation detection in melanoma pat...
# 16     The \\textit{BRAF} V600E mutation in single- i...
# 17     Type I-polarized BRAF-pulsed dendritic cells i...
# 18     Pathogenetic Implications of BRAF Mutation Dis...
# 19     Utility of BRAF V600E Immunohistochemistry Exp...
# 20     Expression of AID in malignant melanoma with B...
# 21     Targeting CPT1A enhances metabolic therapy in ...
# 22     Clinicopathologic findings and BRAF mutation i...
# 23     Differential inhibition of ex-vivo tumor kinas...
# 24     Detection of BRAF gene mutation in primary cho...
# 25     PI3'-kinase inhibition forestalls the onset of...
# 26     p53 Reactivation by PRIMA-1(Met) (APR-246) sen...
# 27     Braf(V600E) cooperates with Pten loss to induc...
# 28     Dabrafenib in advanced melanoma with BRAF V600...
# 29     Diffuse melanosis cutis in the setting of BRAF...
# ...                                                  ...
# 41249  Effects of the Flt3 ITD on response to chemoth...
# 41250  A fast and simple approach for the simultaneou...
# 41251  Sorafenib as treatment for relapsed or refract...
# 41252  Assessment of Molecular Markers in AML Patient...
# 41253  Prognostic significance of the FLT3 ITD mutati...
# 41254  FLT3 mutations in the activation loop of tyros...
# 41255  Analysis of FLT3 length mutations in 1003 pati...
# 41256  Protein-tyrosine phosphatase DEP-1 controls re...
# 41257  The genotype nucleophosmin mutated and FLT3-IT...
# 41258  Abnormalities of p51, p53, FLT3 and N-ras gene...
# 41259  Association of ABCB1 polymorphisms with surviv...
# 41260  Prognostic significance of CEBPA mutations in ...
# 41261  Next-generation sequencing of FLT3 internal ta...
# 41262  Targeting the leukemia microenvironment by CXC...
# 41263  Effects of human FLT3 ligand on myeloid leukem...
# 41264  [Characteristics of karyotypes and gene mutati...
# 41265  Blockade of MEK\/ERK signaling enhances suniti...
# 41266  Exploiting signal transduction pathways in acu...
# 41267  Characterization of a bispecific FLT3 X CD3 an...
# 41268  Misfolded N-CoR is Linked to the Ectopic React...
# 41269  Anchoring of FLT3 in the endoplasmic reticulum...
# 41270  Prognostic significance of FLT3 mutational sta...
# 41271  Novel FLT3 point mutations within exon 14 foun...
# 41272  A Rare Case of Acute Myeloid Leukemia with a t...
# 41273  [AML treatment strategy based on cytogenetic a...
# 41274  Implication of higher BAALC expression in comb...
# 41275  Activating mutations in human acute megakaryob...
# 41276  IDH2 mutations are frequent in Chinese patient...
# 41277  Flt3-ITD alters chemotherapy response in vitro...
# 41278  Molecular evolution of acute myeloid leukaemia...
#
# [41279 rows x 7 columns]

# %%
run_params
# Out:
# {'disease_boost': 1.5,
#  'disease_multi_match_type': 'best_fields',
#  'disease_tie_breaker': 0.4,
#  'gene_boost': 1,
#  'gene_multi_match_type': 'cross_fields',
#  'gene_tie_breaker': 0.5,
#  'query_template': 'submitted/baseline_sex_age.json',
#  'run_id': 'mugctbase1'}

# %%
utils.to_trec_run_file(run, run_params)
