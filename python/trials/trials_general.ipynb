# %% [markdown]
# # TREC 2018 Precision Medicine

# %%
import json
from json2html import *
from IPython.display import HTML
import pandas

import os, sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
from trec_utils import utils, running, evaluation

# %% [raw]
# Load and show configuration

# %%
config = utils.load_config()

# %%
topics_all = utils.get_topics('./topics/topics2017.xml')
qrels_all = utils.get_qrels('./gold-standard/trials.2017.qrels')
#topics_all

# %% [markdown]
# ## Best Runs

# %%
run_params = {
    'run_id':'DEFAULT_RUN',
    'query_template':'tests/baseline-ct.json',
    'disease_tie_breaker':0.4,
    'disease_multi_match_type':'best_fields',
    'disease_boost':1.5,
    'gene_tie_breaker':0.5,
    'gene_multi_match_type':'cross_fields',
    'gene_boost':1
}

run, params = running.run(topics_all, 'TRIALS', run_params)
results, aggregated = evaluation.evaluate(qrels_all, run)

aggregated
# Out:
# RUN: DEFAULT_RUN TOPICS: 30
# {'P_10': 0.3345, 'Rprec': 0.2554, 'ndcg': 0.389, 'recall_1000': 0.4402}

# %%
run_params = {
    'run_id':'DEFAULT_RUN',
    'query_template':'tests/shingles.json',
    'disease_tie_breaker':0.4,
    'disease_multi_match_type':'best_fields',
    'disease_boost':1.5,
    'gene_tie_breaker':0.5,
    'gene_multi_match_type':'best_fields',
    'gene_boost':1
}

run, params = running.run_ct(topics_all, 'TRIALS', run_params)
results, aggregated = evaluation.evaluate(qrels_all, run)

aggregated
# Out:
# RUN: DEFAULT_RUN TOPICS: 30
# {'P_10': 0.3207, 'Rprec': 0.2538, 'ndcg': 0.3935, 'recall_1000': 0.4402}

# %%
run_params = {
    'run_id':'DEFAULT_RUN',
    'query_template':'tests/shingles.json',
    'disease_tie_breaker':0.4,
    'disease_multi_match_type':'best_fields',
    'disease_boost':1.5,
    'gene_tie_breaker':0.5,
    'gene_multi_match_type':'cross_fields',
    'gene_boost':1
}

run, params = running.run_ct(topics_all, run_params)
results, aggregated = evaluation.evaluate(qrels_all, run)

aggregated
# Out:
# RUN: DEFAULT_RUN TOPICS: 30
# {'P_10': 0.3207, 'Rprec': 0.2538, 'ndcg': 0.3935, 'recall_1000': 0.4402}

# %%
run_params = {
    'run_id':'DEFAULT_RUN',
    'query_template':'tests/baseline-ct-exclusion.json',
    'disease_tie_breaker':0.4,
    'disease_multi_match_type':'best_fields',
    'disease_boost':1.5,
    'gene_tie_breaker':0.5,
    'gene_multi_match_type':'cross_fields',
    'gene_boost':1
}

run, params = running.run_ct(topics_all, run_params)
results, aggregated = evaluation.evaluate(qrels_all, run)

aggregated
# Out:
# RUN: DEFAULT_RUN TOPICS: 30
# {'P_10': 0.3034, 'Rprec': 0.1808, 'ndcg': 0.2467, 'recall_1000': 0.2394}

# %%
experiment_params_grid = {
    'query_template':['variable/baseline_sex_age.json'],
    'disease_tie_breaker':[0.4],
    'disease_multi_match_type':['best_fields'],
    'disease_boost':[1.5],
    'gene_tie_breaker':[0.4],
    'gene_multi_match_type':['cross_fields'],
    'gene_boost':[1]
}

results = running.experiment(topics_all, qrels_all, experiment_params_grid)
results
# Out:
# EXPERIMENT BEGIN: 2018-07-30 13:00:15.531581
# RUNS: 1
# 1
# RUN: variable/baseline_sex_age.json-0.4-best_fields-1.5-0.4-cross_fields-1 TOPICS: 30
# ('variable/baseline_sex_age.json', 0.544, 0.52, 0.2817, '0.4', 'best_fields', '1.5', '0.4', 'cross_fields', '1')
# EXPERIMENT END: 2018-07-30 13:00:31.934103
#                          template   ndcg  P_10   Rprec dis_tb  dis_mm_type  \
# 0  variable/baseline_sex_age.json  0.544  0.52  0.2817    0.4  best_fields
#
#   dis_b gene_tb  gene_mm_type gene_b
# 0   1.5     0.4  cross_fields      1

# %% [markdown]
# ## Experiment and do grid search

# %%
# Phrase and phrase prefix give really bad results in the multi match type, discard

experiment_params_grid = {
    'query_template':['variable/baseline_sex_age.json'],
    'disease_tie_breaker':[0.4,0.6],
    'disease_multi_match_type':['best_fields', 'cross_fields'],
    'disease_boost':[1.3,1.6],
    'gene_tie_breaker':[0.4,0.6],
    'gene_multi_match_type':['best_fields', 'cross_fields'],
    'gene_boost':[0.8,1.1]
}

results = running.experiment(topics_all, qrels_all, experiment_params_grid)
# Out:
# EXPERIMENT BEGIN: 2018-07-27 12:47:20.880906
# RUNS: 1458
# 1
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'best_fields', '1', 'best_fields', '0.2', '1')
# 2
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'best_fields', '1', 'best_fields', '0.2', '1.5')
# 3
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'best_fields', '1', 'best_fields', '0.2', '2')
# 4
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'best_fields', '1', 'most_fields', '0.2', '1')
# 5
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'best_fields', '1', 'most_fields', '0.2', '1.5')
# 6
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'best_fields', '1', 'most_fields', '0.2', '2')
# 7
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2571, '0.5', 'best_fields', '1', 'cross_fields', '0.2', '1')
# 8
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4812, 0.4267, 0.2376, '0.5', 'best_fields', '1', 'cross_fields', '0.2', '1.5')
# 9
# RUN: variable/baseline.json-0.5-best_fields-1-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4653, 0.4, 0.2262, '0.5', 'best_fields', '1', 'cross_fields', '0.2', '2')
# 10
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'best_fields', '1', 'best_fields', '0.7', '1')
# 11
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'best_fields', '1', 'best_fields', '0.7', '1.5')
# 12
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'best_fields', '1', 'best_fields', '0.7', '2')
# 13
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'best_fields', '1', 'most_fields', '0.7', '1')
# 14
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'best_fields', '1', 'most_fields', '0.7', '1.5')
# 15
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'best_fields', '1', 'most_fields', '0.7', '2')
# 16
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4759, 0.3967, 0.2386, '0.5', 'best_fields', '1', 'cross_fields', '0.7', '1')
# 17
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4506, 0.3533, 0.2175, '0.5', 'best_fields', '1', 'cross_fields', '0.7', '1.5')
# 18
# RUN: variable/baseline.json-0.5-best_fields-1-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4358, 0.35, 0.2073, '0.5', 'best_fields', '1', 'cross_fields', '0.7', '2')
# 19
# RUN: variable/baseline.json-0.5-best_fields-1-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'best_fields', '1', 'best_fields', '1', '1')
# 20
# RUN: variable/baseline.json-0.5-best_fields-1-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'best_fields', '1', 'best_fields', '1', '1.5')
# 21
# RUN: variable/baseline.json-0.5-best_fields-1-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'best_fields', '1', 'best_fields', '1', '2')
# 22
# RUN: variable/baseline.json-0.5-best_fields-1-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'best_fields', '1', 'most_fields', '1', '1')
# 23
# RUN: variable/baseline.json-0.5-best_fields-1-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'best_fields', '1', 'most_fields', '1', '1.5')
# 24
# RUN: variable/baseline.json-0.5-best_fields-1-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'best_fields', '1', 'most_fields', '1', '2')
# 25
# RUN: variable/baseline.json-0.5-best_fields-1-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4555, 0.37, 0.2247, '0.5', 'best_fields', '1', 'cross_fields', '1', '1')
# 26
# RUN: variable/baseline.json-0.5-best_fields-1-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4338, 0.3533, 0.2067, '0.5', 'best_fields', '1', 'cross_fields', '1', '1.5')
# 27
# RUN: variable/baseline.json-0.5-best_fields-1-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4215, 0.33, 0.1976, '0.5', 'best_fields', '1', 'cross_fields', '1', '2')
# 28
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'best_fields', '1.5', 'best_fields', '0.2', '1')
# 29
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'best_fields', '1.5', 'best_fields', '0.2', '1.5')
# 30
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'best_fields', '1.5', 'best_fields', '0.2', '2')
# 31
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'best_fields', '1.5', 'most_fields', '0.2', '1')
# 32
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'best_fields', '1.5', 'most_fields', '0.2', '1.5')
# 33
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'best_fields', '1.5', 'most_fields', '0.2', '2')
# 34
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2571, '0.5', 'best_fields', '1.5', 'cross_fields', '0.2', '1')
# 35
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4812, 0.4267, 0.2376, '0.5', 'best_fields', '1.5', 'cross_fields', '0.2', '1.5')
# 36
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4653, 0.4, 0.2262, '0.5', 'best_fields', '1.5', 'cross_fields', '0.2', '2')
# 37
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'best_fields', '1.5', 'best_fields', '0.7', '1')
# 38
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'best_fields', '1.5', 'best_fields', '0.7', '1.5')
# 39
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'best_fields', '1.5', 'best_fields', '0.7', '2')
# 40
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'best_fields', '1.5', 'most_fields', '0.7', '1')
# 41
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'best_fields', '1.5', 'most_fields', '0.7', '1.5')
# 42
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'best_fields', '1.5', 'most_fields', '0.7', '2')
# 43
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4759, 0.3967, 0.2386, '0.5', 'best_fields', '1.5', 'cross_fields', '0.7', '1')
# 44
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4506, 0.3533, 0.2175, '0.5', 'best_fields', '1.5', 'cross_fields', '0.7', '1.5')
# 45
# RUN: variable/baseline.json-0.5-best_fields-1.5-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4358, 0.35, 0.2073, '0.5', 'best_fields', '1.5', 'cross_fields', '0.7', '2')
# 46
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'best_fields', '1.5', 'best_fields', '1', '1')
# 47
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'best_fields', '1.5', 'best_fields', '1', '1.5')
# 48
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'best_fields', '1.5', 'best_fields', '1', '2')
# 49
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'best_fields', '1.5', 'most_fields', '1', '1')
# 50
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'best_fields', '1.5', 'most_fields', '1', '1.5')
# 51
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'best_fields', '1.5', 'most_fields', '1', '2')
# 52
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4555, 0.37, 0.2247, '0.5', 'best_fields', '1.5', 'cross_fields', '1', '1')
# 53
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4338, 0.3533, 0.2067, '0.5', 'best_fields', '1.5', 'cross_fields', '1', '1.5')
# 54
# RUN: variable/baseline.json-0.5-best_fields-1.5-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4215, 0.33, 0.1976, '0.5', 'best_fields', '1.5', 'cross_fields', '1', '2')
# 55
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'best_fields', '2', 'best_fields', '0.2', '1')
# 56
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'best_fields', '2', 'best_fields', '0.2', '1.5')
# 57
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'best_fields', '2', 'best_fields', '0.2', '2')
# 58
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'best_fields', '2', 'most_fields', '0.2', '1')
# 59
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'best_fields', '2', 'most_fields', '0.2', '1.5')
# 60
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'best_fields', '2', 'most_fields', '0.2', '2')
# 61
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2571, '0.5', 'best_fields', '2', 'cross_fields', '0.2', '1')
# 62
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4812, 0.4267, 0.2376, '0.5', 'best_fields', '2', 'cross_fields', '0.2', '1.5')
# 63
# RUN: variable/baseline.json-0.5-best_fields-2-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4653, 0.4, 0.2262, '0.5', 'best_fields', '2', 'cross_fields', '0.2', '2')
# 64
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'best_fields', '2', 'best_fields', '0.7', '1')
# 65
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'best_fields', '2', 'best_fields', '0.7', '1.5')
# 66
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'best_fields', '2', 'best_fields', '0.7', '2')
# 67
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'best_fields', '2', 'most_fields', '0.7', '1')
# 68
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'best_fields', '2', 'most_fields', '0.7', '1.5')
# 69
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'best_fields', '2', 'most_fields', '0.7', '2')
# 70
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4759, 0.3967, 0.2386, '0.5', 'best_fields', '2', 'cross_fields', '0.7', '1')
# 71
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4506, 0.3533, 0.2175, '0.5', 'best_fields', '2', 'cross_fields', '0.7', '1.5')
# 72
# RUN: variable/baseline.json-0.5-best_fields-2-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4358, 0.35, 0.2073, '0.5', 'best_fields', '2', 'cross_fields', '0.7', '2')
# 73
# RUN: variable/baseline.json-0.5-best_fields-2-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'best_fields', '2', 'best_fields', '1', '1')
# 74
# RUN: variable/baseline.json-0.5-best_fields-2-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'best_fields', '2', 'best_fields', '1', '1.5')
# 75
# RUN: variable/baseline.json-0.5-best_fields-2-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'best_fields', '2', 'best_fields', '1', '2')
# 76
# RUN: variable/baseline.json-0.5-best_fields-2-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'best_fields', '2', 'most_fields', '1', '1')
# 77
# RUN: variable/baseline.json-0.5-best_fields-2-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'best_fields', '2', 'most_fields', '1', '1.5')
# 78
# RUN: variable/baseline.json-0.5-best_fields-2-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'best_fields', '2', 'most_fields', '1', '2')
# 79
# RUN: variable/baseline.json-0.5-best_fields-2-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4555, 0.37, 0.2247, '0.5', 'best_fields', '2', 'cross_fields', '1', '1')
# 80
# RUN: variable/baseline.json-0.5-best_fields-2-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4338, 0.3533, 0.2067, '0.5', 'best_fields', '2', 'cross_fields', '1', '1.5')
# 81
# RUN: variable/baseline.json-0.5-best_fields-2-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4215, 0.33, 0.1976, '0.5', 'best_fields', '2', 'cross_fields', '1', '2')
# 82
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'most_fields', '1', 'best_fields', '0.2', '1')
# 83
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'most_fields', '1', 'best_fields', '0.2', '1.5')
# 84
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'most_fields', '1', 'best_fields', '0.2', '2')
# 85
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'most_fields', '1', 'most_fields', '0.2', '1')
# 86
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'most_fields', '1', 'most_fields', '0.2', '1.5')
# 87
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'most_fields', '1', 'most_fields', '0.2', '2')
# 88
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2571, '0.5', 'most_fields', '1', 'cross_fields', '0.2', '1')
# 89
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4812, 0.4267, 0.2376, '0.5', 'most_fields', '1', 'cross_fields', '0.2', '1.5')
# 90
# RUN: variable/baseline.json-0.5-most_fields-1-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4653, 0.4, 0.2262, '0.5', 'most_fields', '1', 'cross_fields', '0.2', '2')
# 91
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'most_fields', '1', 'best_fields', '0.7', '1')
# 92
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'most_fields', '1', 'best_fields', '0.7', '1.5')
# 93
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'most_fields', '1', 'best_fields', '0.7', '2')
# 94
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'most_fields', '1', 'most_fields', '0.7', '1')
# 95
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'most_fields', '1', 'most_fields', '0.7', '1.5')
# 96
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'most_fields', '1', 'most_fields', '0.7', '2')
# 97
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4759, 0.3967, 0.2386, '0.5', 'most_fields', '1', 'cross_fields', '0.7', '1')
# 98
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4506, 0.3533, 0.2175, '0.5', 'most_fields', '1', 'cross_fields', '0.7', '1.5')
# 99
# RUN: variable/baseline.json-0.5-most_fields-1-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4358, 0.35, 0.2073, '0.5', 'most_fields', '1', 'cross_fields', '0.7', '2')
# 100
# RUN: variable/baseline.json-0.5-most_fields-1-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'most_fields', '1', 'best_fields', '1', '1')
# 101
# RUN: variable/baseline.json-0.5-most_fields-1-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'most_fields', '1', 'best_fields', '1', '1.5')
# 102
# RUN: variable/baseline.json-0.5-most_fields-1-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'most_fields', '1', 'best_fields', '1', '2')
# 103
# RUN: variable/baseline.json-0.5-most_fields-1-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'most_fields', '1', 'most_fields', '1', '1')
# 104
# RUN: variable/baseline.json-0.5-most_fields-1-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'most_fields', '1', 'most_fields', '1', '1.5')
# 105
# RUN: variable/baseline.json-0.5-most_fields-1-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'most_fields', '1', 'most_fields', '1', '2')
# 106
# RUN: variable/baseline.json-0.5-most_fields-1-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4555, 0.37, 0.2247, '0.5', 'most_fields', '1', 'cross_fields', '1', '1')
# 107
# RUN: variable/baseline.json-0.5-most_fields-1-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4338, 0.3533, 0.2067, '0.5', 'most_fields', '1', 'cross_fields', '1', '1.5')
# 108
# RUN: variable/baseline.json-0.5-most_fields-1-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4215, 0.33, 0.1976, '0.5', 'most_fields', '1', 'cross_fields', '1', '2')
# 109
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'most_fields', '1.5', 'best_fields', '0.2', '1')
# 110
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'most_fields', '1.5', 'best_fields', '0.2', '1.5')
# 111
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'most_fields', '1.5', 'best_fields', '0.2', '2')
# 112
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'most_fields', '1.5', 'most_fields', '0.2', '1')
# 113
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'most_fields', '1.5', 'most_fields', '0.2', '1.5')
# 114
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'most_fields', '1.5', 'most_fields', '0.2', '2')
# 115
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2571, '0.5', 'most_fields', '1.5', 'cross_fields', '0.2', '1')
# 116
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4812, 0.4267, 0.2376, '0.5', 'most_fields', '1.5', 'cross_fields', '0.2', '1.5')
# 117
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4653, 0.4, 0.2262, '0.5', 'most_fields', '1.5', 'cross_fields', '0.2', '2')
# 118
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'most_fields', '1.5', 'best_fields', '0.7', '1')
# 119
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'most_fields', '1.5', 'best_fields', '0.7', '1.5')
# 120
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'most_fields', '1.5', 'best_fields', '0.7', '2')
# 121
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'most_fields', '1.5', 'most_fields', '0.7', '1')
# 122
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'most_fields', '1.5', 'most_fields', '0.7', '1.5')
# 123
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'most_fields', '1.5', 'most_fields', '0.7', '2')
# 124
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4759, 0.3967, 0.2386, '0.5', 'most_fields', '1.5', 'cross_fields', '0.7', '1')
# 125
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4506, 0.3533, 0.2175, '0.5', 'most_fields', '1.5', 'cross_fields', '0.7', '1.5')
# 126
# RUN: variable/baseline.json-0.5-most_fields-1.5-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4358, 0.35, 0.2073, '0.5', 'most_fields', '1.5', 'cross_fields', '0.7', '2')
# 127
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'most_fields', '1.5', 'best_fields', '1', '1')
# 128
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'most_fields', '1.5', 'best_fields', '1', '1.5')
# 129
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'most_fields', '1.5', 'best_fields', '1', '2')
# 130
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'most_fields', '1.5', 'most_fields', '1', '1')
# 131
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'most_fields', '1.5', 'most_fields', '1', '1.5')
# 132
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'most_fields', '1.5', 'most_fields', '1', '2')
# 133
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4555, 0.37, 0.2247, '0.5', 'most_fields', '1.5', 'cross_fields', '1', '1')
# 134
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4338, 0.3533, 0.2067, '0.5', 'most_fields', '1.5', 'cross_fields', '1', '1.5')
# 135
# RUN: variable/baseline.json-0.5-most_fields-1.5-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4215, 0.33, 0.1976, '0.5', 'most_fields', '1.5', 'cross_fields', '1', '2')
# 136
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'most_fields', '2', 'best_fields', '0.2', '1')
# 137
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'most_fields', '2', 'best_fields', '0.2', '1.5')
# 138
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'most_fields', '2', 'best_fields', '0.2', '2')
# 139
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5074, 0.4467, 0.2539, '0.5', 'most_fields', '2', 'most_fields', '0.2', '1')
# 140
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4783, 0.4033, 0.2364, '0.5', 'most_fields', '2', 'most_fields', '0.2', '1.5')
# 141
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4633, 0.3867, 0.2248, '0.5', 'most_fields', '2', 'most_fields', '0.2', '2')
# 142
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2571, '0.5', 'most_fields', '2', 'cross_fields', '0.2', '1')
# 143
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4812, 0.4267, 0.2376, '0.5', 'most_fields', '2', 'cross_fields', '0.2', '1.5')
# 144
# RUN: variable/baseline.json-0.5-most_fields-2-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4653, 0.4, 0.2262, '0.5', 'most_fields', '2', 'cross_fields', '0.2', '2')
# 145
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'most_fields', '2', 'best_fields', '0.7', '1')
# 146
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'most_fields', '2', 'best_fields', '0.7', '1.5')
# 147
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'most_fields', '2', 'best_fields', '0.7', '2')
# 148
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4664, 0.38, 0.229, '0.5', 'most_fields', '2', 'most_fields', '0.7', '1')
# 149
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4449, 0.3633, 0.215, '0.5', 'most_fields', '2', 'most_fields', '0.7', '1.5')
# 150
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4301, 0.35, 0.2052, '0.5', 'most_fields', '2', 'most_fields', '0.7', '2')
# 151
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4759, 0.3967, 0.2386, '0.5', 'most_fields', '2', 'cross_fields', '0.7', '1')
# 152
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4506, 0.3533, 0.2175, '0.5', 'most_fields', '2', 'cross_fields', '0.7', '1.5')
# 153
# RUN: variable/baseline.json-0.5-most_fields-2-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4358, 0.35, 0.2073, '0.5', 'most_fields', '2', 'cross_fields', '0.7', '2')
# 154
# RUN: variable/baseline.json-0.5-most_fields-2-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'most_fields', '2', 'best_fields', '1', '1')
# 155
# RUN: variable/baseline.json-0.5-most_fields-2-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'most_fields', '2', 'best_fields', '1', '1.5')
# 156
# RUN: variable/baseline.json-0.5-most_fields-2-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'most_fields', '2', 'best_fields', '1', '2')
# 157
# RUN: variable/baseline.json-0.5-most_fields-2-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4478, 0.3533, 0.2182, '0.5', 'most_fields', '2', 'most_fields', '1', '1')
# 158
# RUN: variable/baseline.json-0.5-most_fields-2-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4259, 0.3433, 0.2014, '0.5', 'most_fields', '2', 'most_fields', '1', '1.5')
# 159
# RUN: variable/baseline.json-0.5-most_fields-2-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4148, 0.32, 0.1938, '0.5', 'most_fields', '2', 'most_fields', '1', '2')
# 160
# RUN: variable/baseline.json-0.5-most_fields-2-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4555, 0.37, 0.2247, '0.5', 'most_fields', '2', 'cross_fields', '1', '1')
# 161
# RUN: variable/baseline.json-0.5-most_fields-2-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4338, 0.3533, 0.2067, '0.5', 'most_fields', '2', 'cross_fields', '1', '1.5')
# 162
# RUN: variable/baseline.json-0.5-most_fields-2-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4215, 0.33, 0.1976, '0.5', 'most_fields', '2', 'cross_fields', '1', '2')
# 163
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5045, 0.4533, 0.2521, '0.5', 'cross_fields', '1', 'best_fields', '0.2', '1')
# 164
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4766, 0.41, 0.2359, '0.5', 'cross_fields', '1', 'best_fields', '0.2', '1.5')
# 165
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4626, 0.39, 0.2235, '0.5', 'cross_fields', '1', 'best_fields', '0.2', '2')
# 166
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5045, 0.4533, 0.2521, '0.5', 'cross_fields', '1', 'most_fields', '0.2', '1')
# 167
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4766, 0.41, 0.2359, '0.5', 'cross_fields', '1', 'most_fields', '0.2', '1.5')
# 168
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4626, 0.39, 0.2235, '0.5', 'cross_fields', '1', 'most_fields', '0.2', '2')
# 169
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.509, 0.45, 0.254, '0.5', 'cross_fields', '1', 'cross_fields', '0.2', '1')
# 170
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.48, 0.4133, 0.2363, '0.5', 'cross_fields', '1', 'cross_fields', '0.2', '1.5')
# 171
# RUN: variable/baseline.json-0.5-cross_fields-1-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4644, 0.3967, 0.2255, '0.5', 'cross_fields', '1', 'cross_fields', '0.2', '2')
# 172
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.465, 0.38, 0.2288, '0.5', 'cross_fields', '1', 'best_fields', '0.7', '1')
# 173
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4426, 0.36, 0.2135, '0.5', 'cross_fields', '1', 'best_fields', '0.7', '1.5')
# 174
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.429, 0.3467, 0.203, '0.5', 'cross_fields', '1', 'best_fields', '0.7', '2')
# 175
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.465, 0.38, 0.2288, '0.5', 'cross_fields', '1', 'most_fields', '0.7', '1')
# 176
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4426, 0.36, 0.2135, '0.5', 'cross_fields', '1', 'most_fields', '0.7', '1.5')
# 177
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.429, 0.3467, 0.203, '0.5', 'cross_fields', '1', 'most_fields', '0.7', '2')
# 178
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4738, 0.3967, 0.2375, '0.5', 'cross_fields', '1', 'cross_fields', '0.7', '1')
# 179
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4488, 0.3567, 0.2164, '0.5', 'cross_fields', '1', 'cross_fields', '0.7', '1.5')
# 180
# RUN: variable/baseline.json-0.5-cross_fields-1-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4345, 0.35, 0.2052, '0.5', 'cross_fields', '1', 'cross_fields', '0.7', '2')
# 181
# RUN: variable/baseline.json-0.5-cross_fields-1-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.445, 0.3533, 0.2164, '0.5', 'cross_fields', '1', 'best_fields', '1', '1')
# 182
# RUN: variable/baseline.json-0.5-cross_fields-1-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4235, 0.34, 0.2004, '0.5', 'cross_fields', '1', 'best_fields', '1', '1.5')
# 183
# RUN: variable/baseline.json-0.5-cross_fields-1-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4132, 0.32, 0.1917, '0.5', 'cross_fields', '1', 'best_fields', '1', '2')
# 184
# RUN: variable/baseline.json-0.5-cross_fields-1-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.445, 0.3533, 0.2164, '0.5', 'cross_fields', '1', 'most_fields', '1', '1')
# 185
# RUN: variable/baseline.json-0.5-cross_fields-1-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4235, 0.34, 0.2004, '0.5', 'cross_fields', '1', 'most_fields', '1', '1.5')
# 186
# RUN: variable/baseline.json-0.5-cross_fields-1-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4132, 0.32, 0.1917, '0.5', 'cross_fields', '1', 'most_fields', '1', '2')
# 187
# RUN: variable/baseline.json-0.5-cross_fields-1-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4545, 0.3633, 0.2221, '0.5', 'cross_fields', '1', 'cross_fields', '1', '1')
# 188
# RUN: variable/baseline.json-0.5-cross_fields-1-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.432, 0.3433, 0.206, '0.5', 'cross_fields', '1', 'cross_fields', '1', '1.5')
# 189
# RUN: variable/baseline.json-0.5-cross_fields-1-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4203, 0.3267, 0.1968, '0.5', 'cross_fields', '1', 'cross_fields', '1', '2')
# 190
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5045, 0.4533, 0.2521, '0.5', 'cross_fields', '1.5', 'best_fields', '0.2', '1')
# 191
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4766, 0.41, 0.2359, '0.5', 'cross_fields', '1.5', 'best_fields', '0.2', '1.5')
# 192
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4626, 0.39, 0.2235, '0.5', 'cross_fields', '1.5', 'best_fields', '0.2', '2')
# 193
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5045, 0.4533, 0.2521, '0.5', 'cross_fields', '1.5', 'most_fields', '0.2', '1')
# 194
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4766, 0.41, 0.2359, '0.5', 'cross_fields', '1.5', 'most_fields', '0.2', '1.5')
# 195
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4626, 0.39, 0.2235, '0.5', 'cross_fields', '1.5', 'most_fields', '0.2', '2')
# 196
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.509, 0.45, 0.254, '0.5', 'cross_fields', '1.5', 'cross_fields', '0.2', '1')
# 197
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.48, 0.4133, 0.2363, '0.5', 'cross_fields', '1.5', 'cross_fields', '0.2', '1.5')
# 198
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4644, 0.3967, 0.2255, '0.5', 'cross_fields', '1.5', 'cross_fields', '0.2', '2')
# 199
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.465, 0.38, 0.2288, '0.5', 'cross_fields', '1.5', 'best_fields', '0.7', '1')
# 200
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4426, 0.36, 0.2135, '0.5', 'cross_fields', '1.5', 'best_fields', '0.7', '1.5')
# 201
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.429, 0.3467, 0.203, '0.5', 'cross_fields', '1.5', 'best_fields', '0.7', '2')
# 202
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.465, 0.38, 0.2288, '0.5', 'cross_fields', '1.5', 'most_fields', '0.7', '1')
# 203
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4426, 0.36, 0.2135, '0.5', 'cross_fields', '1.5', 'most_fields', '0.7', '1.5')
# 204
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.429, 0.3467, 0.203, '0.5', 'cross_fields', '1.5', 'most_fields', '0.7', '2')
# 205
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4738, 0.3967, 0.2375, '0.5', 'cross_fields', '1.5', 'cross_fields', '0.7', '1')
# 206
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4488, 0.3567, 0.2164, '0.5', 'cross_fields', '1.5', 'cross_fields', '0.7', '1.5')
# 207
# RUN: variable/baseline.json-0.5-cross_fields-1.5-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4345, 0.35, 0.2052, '0.5', 'cross_fields', '1.5', 'cross_fields', '0.7', '2')
# 208
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.445, 0.3533, 0.2164, '0.5', 'cross_fields', '1.5', 'best_fields', '1', '1')
# 209
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4235, 0.34, 0.2004, '0.5', 'cross_fields', '1.5', 'best_fields', '1', '1.5')
# 210
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4132, 0.32, 0.1917, '0.5', 'cross_fields', '1.5', 'best_fields', '1', '2')
# 211
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.445, 0.3533, 0.2164, '0.5', 'cross_fields', '1.5', 'most_fields', '1', '1')
# 212
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4235, 0.34, 0.2004, '0.5', 'cross_fields', '1.5', 'most_fields', '1', '1.5')
# 213
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4132, 0.32, 0.1917, '0.5', 'cross_fields', '1.5', 'most_fields', '1', '2')
# 214
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4545, 0.3633, 0.2221, '0.5', 'cross_fields', '1.5', 'cross_fields', '1', '1')
# 215
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.432, 0.3433, 0.206, '0.5', 'cross_fields', '1.5', 'cross_fields', '1', '1.5')
# 216
# RUN: variable/baseline.json-0.5-cross_fields-1.5-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4203, 0.3267, 0.1968, '0.5', 'cross_fields', '1.5', 'cross_fields', '1', '2')
# 217
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5045, 0.4533, 0.2521, '0.5', 'cross_fields', '2', 'best_fields', '0.2', '1')
# 218
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4766, 0.41, 0.2359, '0.5', 'cross_fields', '2', 'best_fields', '0.2', '1.5')
# 219
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4626, 0.39, 0.2235, '0.5', 'cross_fields', '2', 'best_fields', '0.2', '2')
# 220
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5045, 0.4533, 0.2521, '0.5', 'cross_fields', '2', 'most_fields', '0.2', '1')
# 221
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4766, 0.41, 0.2359, '0.5', 'cross_fields', '2', 'most_fields', '0.2', '1.5')
# 222
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4626, 0.39, 0.2235, '0.5', 'cross_fields', '2', 'most_fields', '0.2', '2')
# 223
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.509, 0.45, 0.254, '0.5', 'cross_fields', '2', 'cross_fields', '0.2', '1')
# 224
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.48, 0.4133, 0.2363, '0.5', 'cross_fields', '2', 'cross_fields', '0.2', '1.5')
# 225
# RUN: variable/baseline.json-0.5-cross_fields-2-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4644, 0.3967, 0.2255, '0.5', 'cross_fields', '2', 'cross_fields', '0.2', '2')
# 226
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.465, 0.38, 0.2288, '0.5', 'cross_fields', '2', 'best_fields', '0.7', '1')
# 227
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4426, 0.36, 0.2135, '0.5', 'cross_fields', '2', 'best_fields', '0.7', '1.5')
# 228
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.429, 0.3467, 0.203, '0.5', 'cross_fields', '2', 'best_fields', '0.7', '2')
# 229
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.465, 0.38, 0.2288, '0.5', 'cross_fields', '2', 'most_fields', '0.7', '1')
# 230
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4426, 0.36, 0.2135, '0.5', 'cross_fields', '2', 'most_fields', '0.7', '1.5')
# 231
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.429, 0.3467, 0.203, '0.5', 'cross_fields', '2', 'most_fields', '0.7', '2')
# 232
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4738, 0.3967, 0.2375, '0.5', 'cross_fields', '2', 'cross_fields', '0.7', '1')
# 233
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4488, 0.3567, 0.2164, '0.5', 'cross_fields', '2', 'cross_fields', '0.7', '1.5')
# 234
# RUN: variable/baseline.json-0.5-cross_fields-2-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4345, 0.35, 0.2052, '0.5', 'cross_fields', '2', 'cross_fields', '0.7', '2')
# 235
# RUN: variable/baseline.json-0.5-cross_fields-2-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.445, 0.3533, 0.2164, '0.5', 'cross_fields', '2', 'best_fields', '1', '1')
# 236
# RUN: variable/baseline.json-0.5-cross_fields-2-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4235, 0.34, 0.2004, '0.5', 'cross_fields', '2', 'best_fields', '1', '1.5')
# 237
# RUN: variable/baseline.json-0.5-cross_fields-2-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4132, 0.32, 0.1917, '0.5', 'cross_fields', '2', 'best_fields', '1', '2')
# 238
# RUN: variable/baseline.json-0.5-cross_fields-2-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.445, 0.3533, 0.2164, '0.5', 'cross_fields', '2', 'most_fields', '1', '1')
# 239
# RUN: variable/baseline.json-0.5-cross_fields-2-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4235, 0.34, 0.2004, '0.5', 'cross_fields', '2', 'most_fields', '1', '1.5')
# 240
# RUN: variable/baseline.json-0.5-cross_fields-2-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4132, 0.32, 0.1917, '0.5', 'cross_fields', '2', 'most_fields', '1', '2')
# 241
# RUN: variable/baseline.json-0.5-cross_fields-2-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4545, 0.3633, 0.2221, '0.5', 'cross_fields', '2', 'cross_fields', '1', '1')
# 242
# RUN: variable/baseline.json-0.5-cross_fields-2-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.432, 0.3433, 0.206, '0.5', 'cross_fields', '2', 'cross_fields', '1', '1.5')
# 243
# RUN: variable/baseline.json-0.5-cross_fields-2-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4203, 0.3267, 0.1968, '0.5', 'cross_fields', '2', 'cross_fields', '1', '2')
# 244
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5331, 0.48, 0.2698, '0.7', 'best_fields', '1', 'best_fields', '0.2', '1')
# 245
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5124, 0.45, 0.2589, '0.7', 'best_fields', '1', 'best_fields', '0.2', '1.5')
# 246
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4911, 0.4233, 0.2439, '0.7', 'best_fields', '1', 'best_fields', '0.2', '2')
# 247
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5331, 0.48, 0.2698, '0.7', 'best_fields', '1', 'most_fields', '0.2', '1')
# 248
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5124, 0.45, 0.2589, '0.7', 'best_fields', '1', 'most_fields', '0.2', '1.5')
# 249
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4911, 0.4233, 0.2439, '0.7', 'best_fields', '1', 'most_fields', '0.2', '2')
# 250
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5345, 0.4667, 0.2686, '0.7', 'best_fields', '1', 'cross_fields', '0.2', '1')
# 251
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5145, 0.4433, 0.2601, '0.7', 'best_fields', '1', 'cross_fields', '0.2', '1.5')
# 252
# RUN: variable/baseline.json-0.7-best_fields-1-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4929, 0.4267, 0.2466, '0.7', 'best_fields', '1', 'cross_fields', '0.2', '2')
# 253
# RUN: variable/baseline.json-0.7-best_fields-1-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4968, 0.4233, 0.2619, '0.7', 'best_fields', '1', 'best_fields', '0.7', '1')
# 254
# RUN: variable/baseline.json-0.7-best_fields-1-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4705, 0.3733, 0.2347, '0.7', 'best_fields', '1', 'best_fields', '0.7', '1.5')
# 255
# RUN: variable/baseline.json-0.7-best_fields-1-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4527, 0.37, 0.2194, '0.7', 'best_fields', '1', 'best_fields', '0.7', '2')
# 256
# RUN: variable/baseline.json-0.7-best_fields-1-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.4968, 0.4233, 0.2619, '0.7', 'best_fields', '1', 'most_fields', '0.7', '1')
# 257
# RUN: variable/baseline.json-0.7-best_fields-1-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4705, 0.3733, 0.2347, '0.7', 'best_fields', '1', 'most_fields', '0.7', '1.5')
# 258
# RUN: variable/baseline.json-0.7-best_fields-1-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4527, 0.37, 0.2194, '0.7', 'best_fields', '1', 'most_fields', '0.7', '2')
# 259
# RUN: variable/baseline.json-0.7-best_fields-1-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5038, 0.44, 0.2654, '0.7', 'best_fields', '1', 'cross_fields', '0.7', '1')
# 260
# ...
# 618
# RUN: variable/baseline.json-1-most_fields-1.5-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4663, 0.37, 0.2357, '1', 'most_fields', '1.5', 'most_fields', '1', '2')
# 619
# RUN: variable/baseline.json-1-most_fields-1.5-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2711, '1', 'most_fields', '1.5', 'cross_fields', '1', '1')
# 620
# RUN: variable/baseline.json-1-most_fields-1.5-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4952, 0.42, 0.2621, '1', 'most_fields', '1.5', 'cross_fields', '1', '1.5')
# 621
# RUN: variable/baseline.json-1-most_fields-1.5-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4761, 0.3833, 0.2409, '1', 'most_fields', '1.5', 'cross_fields', '1', '2')
# 622
# RUN: variable/baseline.json-1-most_fields-2-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5316, 0.47, 0.2678, '1', 'most_fields', '2', 'best_fields', '0.2', '1')
# 623
# RUN: variable/baseline.json-1-most_fields-2-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5342, 0.46, 0.2715, '1', 'most_fields', '2', 'best_fields', '0.2', '1.5')
# 624
# RUN: variable/baseline.json-1-most_fields-2-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.5274, 0.4767, 0.2613, '1', 'most_fields', '2', 'best_fields', '0.2', '2')
# 625
# RUN: variable/baseline.json-1-most_fields-2-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5316, 0.47, 0.2678, '1', 'most_fields', '2', 'most_fields', '0.2', '1')
# 626
# RUN: variable/baseline.json-1-most_fields-2-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5342, 0.46, 0.2715, '1', 'most_fields', '2', 'most_fields', '0.2', '1.5')
# 627
# RUN: variable/baseline.json-1-most_fields-2-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.5274, 0.4767, 0.2613, '1', 'most_fields', '2', 'most_fields', '0.2', '2')
# 628
# RUN: variable/baseline.json-1-most_fields-2-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5335, 0.47, 0.2702, '1', 'most_fields', '2', 'cross_fields', '0.2', '1')
# 629
# RUN: variable/baseline.json-1-most_fields-2-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5359, 0.4667, 0.2715, '1', 'most_fields', '2', 'cross_fields', '0.2', '1.5')
# 630
# RUN: variable/baseline.json-1-most_fields-2-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.529, 0.48, 0.2617, '1', 'most_fields', '2', 'cross_fields', '0.2', '2')
# 631
# RUN: variable/baseline.json-1-most_fields-2-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5181, 0.4467, 0.2698, '1', 'most_fields', '2', 'best_fields', '0.7', '1')
# 632
# RUN: variable/baseline.json-1-most_fields-2-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5027, 0.43, 0.2647, '1', 'most_fields', '2', 'best_fields', '0.7', '1.5')
# 633
# RUN: variable/baseline.json-1-most_fields-2-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4848, 0.4067, 0.2477, '1', 'most_fields', '2', 'best_fields', '0.7', '2')
# 634
# RUN: variable/baseline.json-1-most_fields-2-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5181, 0.4467, 0.2698, '1', 'most_fields', '2', 'most_fields', '0.7', '1')
# 635
# RUN: variable/baseline.json-1-most_fields-2-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5027, 0.43, 0.2647, '1', 'most_fields', '2', 'most_fields', '0.7', '1.5')
# 636
# RUN: variable/baseline.json-1-most_fields-2-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4848, 0.4067, 0.2477, '1', 'most_fields', '2', 'most_fields', '0.7', '2')
# 637
# RUN: variable/baseline.json-1-most_fields-2-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5246, 0.4533, 0.2784, '1', 'most_fields', '2', 'cross_fields', '0.7', '1')
# 638
# RUN: variable/baseline.json-1-most_fields-2-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5103, 0.4367, 0.2689, '1', 'most_fields', '2', 'cross_fields', '0.7', '1.5')
# 639
# RUN: variable/baseline.json-1-most_fields-2-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4922, 0.4133, 0.2546, '1', 'most_fields', '2', 'cross_fields', '0.7', '2')
# 640
# RUN: variable/baseline.json-1-most_fields-2-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5057, 0.45, 0.2674, '1', 'most_fields', '2', 'best_fields', '1', '1')
# 641
# RUN: variable/baseline.json-1-most_fields-2-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4843, 0.4067, 0.2522, '1', 'most_fields', '2', 'best_fields', '1', '1.5')
# 642
# RUN: variable/baseline.json-1-most_fields-2-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4663, 0.37, 0.2357, '1', 'most_fields', '2', 'best_fields', '1', '2')
# 643
# RUN: variable/baseline.json-1-most_fields-2-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5057, 0.45, 0.2674, '1', 'most_fields', '2', 'most_fields', '1', '1')
# 644
# RUN: variable/baseline.json-1-most_fields-2-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4843, 0.4067, 0.2522, '1', 'most_fields', '2', 'most_fields', '1', '1.5')
# 645
# RUN: variable/baseline.json-1-most_fields-2-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4663, 0.37, 0.2357, '1', 'most_fields', '2', 'most_fields', '1', '2')
# 646
# RUN: variable/baseline.json-1-most_fields-2-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5119, 0.4467, 0.2711, '1', 'most_fields', '2', 'cross_fields', '1', '1')
# 647
# RUN: variable/baseline.json-1-most_fields-2-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4952, 0.42, 0.2621, '1', 'most_fields', '2', 'cross_fields', '1', '1.5')
# 648
# RUN: variable/baseline.json-1-most_fields-2-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4761, 0.3833, 0.2409, '1', 'most_fields', '2', 'cross_fields', '1', '2')
# 649
# RUN: variable/baseline.json-1-cross_fields-1-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5336, 0.4733, 0.2709, '1', 'cross_fields', '1', 'best_fields', '0.2', '1')
# 650
# RUN: variable/baseline.json-1-cross_fields-1-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5341, 0.4767, 0.2738, '1', 'cross_fields', '1', 'best_fields', '0.2', '1.5')
# 651
# RUN: variable/baseline.json-1-cross_fields-1-0.2-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.5217, 0.47, 0.264, '1', 'cross_fields', '1', 'best_fields', '0.2', '2')
# 652
# RUN: variable/baseline.json-1-cross_fields-1-0.2-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5336, 0.4733, 0.2709, '1', 'cross_fields', '1', 'most_fields', '0.2', '1')
# 653
# RUN: variable/baseline.json-1-cross_fields-1-0.2-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5341, 0.4767, 0.2738, '1', 'cross_fields', '1', 'most_fields', '0.2', '1.5')
# 654
# RUN: variable/baseline.json-1-cross_fields-1-0.2-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.5217, 0.47, 0.264, '1', 'cross_fields', '1', 'most_fields', '0.2', '2')
# 655
# RUN: variable/baseline.json-1-cross_fields-1-0.2-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5353, 0.4733, 0.2709, '1', 'cross_fields', '1', 'cross_fields', '0.2', '1')
# 656
# RUN: variable/baseline.json-1-cross_fields-1-0.2-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5349, 0.4733, 0.2711, '1', 'cross_fields', '1', 'cross_fields', '0.2', '1.5')
# 657
# RUN: variable/baseline.json-1-cross_fields-1-0.2-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.5262, 0.46, 0.2664, '1', 'cross_fields', '1', 'cross_fields', '0.2', '2')
# 658
# RUN: variable/baseline.json-1-cross_fields-1-0.7-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5162, 0.4433, 0.2716, '1', 'cross_fields', '1', 'best_fields', '0.7', '1')
# 659
# RUN: variable/baseline.json-1-cross_fields-1-0.7-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5012, 0.4267, 0.2653, '1', 'cross_fields', '1', 'best_fields', '0.7', '1.5')
# 660
# RUN: variable/baseline.json-1-cross_fields-1-0.7-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4824, 0.3967, 0.2476, '1', 'cross_fields', '1', 'best_fields', '0.7', '2')
# 661
# RUN: variable/baseline.json-1-cross_fields-1-0.7-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5162, 0.4433, 0.2716, '1', 'cross_fields', '1', 'most_fields', '0.7', '1')
# 662
# RUN: variable/baseline.json-1-cross_fields-1-0.7-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5012, 0.4267, 0.2653, '1', 'cross_fields', '1', 'most_fields', '0.7', '1.5')
# 663
# RUN: variable/baseline.json-1-cross_fields-1-0.7-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4824, 0.3967, 0.2476, '1', 'cross_fields', '1', 'most_fields', '0.7', '2')
# 664
# RUN: variable/baseline.json-1-cross_fields-1-0.7-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5241, 0.4533, 0.2777, '1', 'cross_fields', '1', 'cross_fields', '0.7', '1')
# 665
# RUN: variable/baseline.json-1-cross_fields-1-0.7-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5083, 0.43, 0.2681, '1', 'cross_fields', '1', 'cross_fields', '0.7', '1.5')
# 666
# RUN: variable/baseline.json-1-cross_fields-1-0.7-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4893, 0.4033, 0.2531, '1', 'cross_fields', '1', 'cross_fields', '0.7', '2')
# 667
# RUN: variable/baseline.json-1-cross_fields-1-1-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5041, 0.4467, 0.2691, '1', 'cross_fields', '1', 'best_fields', '1', '1')
# 668
# RUN: variable/baseline.json-1-cross_fields-1-1-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4818, 0.3933, 0.2529, '1', 'cross_fields', '1', 'best_fields', '1', '1.5')
# 669
# RUN: variable/baseline.json-1-cross_fields-1-1-best_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4637, 0.3667, 0.2333, '1', 'cross_fields', '1', 'best_fields', '1', '2')
# 670
# RUN: variable/baseline.json-1-cross_fields-1-1-most_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5041, 0.4467, 0.2691, '1', 'cross_fields', '1', 'most_fields', '1', '1')
# 671
# RUN: variable/baseline.json-1-cross_fields-1-1-most_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4818, 0.3933, 0.2529, '1', 'cross_fields', '1', 'most_fields', '1', '1.5')
# 672
# RUN: variable/baseline.json-1-cross_fields-1-1-most_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4637, 0.3667, 0.2333, '1', 'cross_fields', '1', 'most_fields', '1', '2')
# 673
# RUN: variable/baseline.json-1-cross_fields-1-1-cross_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5104, 0.4533, 0.2698, '1', 'cross_fields', '1', 'cross_fields', '1', '1')
# 674
# RUN: variable/baseline.json-1-cross_fields-1-1-cross_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.4912, 0.4167, 0.26, '1', 'cross_fields', '1', 'cross_fields', '1', '1.5')
# 675
# RUN: variable/baseline.json-1-cross_fields-1-1-cross_fields-2 TOPICS: 30
# ('variable/baseline.json', 0.4737, 0.38, 0.2385, '1', 'cross_fields', '1', 'cross_fields', '1', '2')
# 676
# RUN: variable/baseline.json-1-cross_fields-1.5-0.2-best_fields-1 TOPICS: 30
# ('variable/baseline.json', 0.5336, 0.4733, 0.2709, '1', 'cross_fields', '1.5', 'best_fields', '0.2', '1')
# 677
# RUN: variable/baseline.json-1-cross_fields-1.5-0.2-best_fields-1.5 TOPICS: 30
# ('variable/baseline.json', 0.5341, 0.4767, 0.2738, '1', 'cross_fields', '1.5', 'best_fields', '0.2', '1.5')
# 678
# RUN: variable/baseline.json-1-cross_fields-1.5-0.2-best_fields-2 TOPICS: 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f4c118b9170b> in <module>()
#      11 }
#      12
# ---> 13 results = running.experiment(topics_all, qrels_all, experiment_params_grid)
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/trec_utils/running.py in experiment(topics_df, qrels_df, params_grid)
#     104                                     'gene_multi_match_type':gmmt,
#     105                                     'gene_boost':str(gb)
# --> 106                                 }
#     107                                 print(run_number)
#     108                                 run_df, run_params_df = run(topics_df, params)
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/trec_utils/running.py in run(topics_df, run_params)
#      49           query = query.replace('{{gene_tie_breaker}}', str(run_params['gene_tie_breaker']))
#      50           query = query.replace('{{gene_multi_match_type}}', run_params['gene_multi_match_type'])
# ---> 51           query = query.replace('{{gene_boost}}', str(run_params['gene_boost']))
#      52
#      53         response = requests.post(URL, data=query, headers=HEADERS)
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     110     """
#     111
# --> 112     return request('post', url, data=data, json=json, **kwargs)
#     113
#     114
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     660
#     661         if not stream:
# --> 662             r.content
#     663
#     664         return r
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/requests/models.py in content(self)
#     825                 self._content = None
#     826             else:
# --> 827                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     828
#     829         self._content_consumed = True
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/requests/models.py in generate()
#     747             if hasattr(self.raw, 'stream'):
#     748                 try:
# --> 749                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     750                         yield chunk
#     751                 except ProtocolError as e:
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     599                 if self.chunk_left == 0:
#     600                     break
# --> 601                 chunk = self._handle_chunk(amt)
#     602                 decoded = self._decode(chunk, decode_content=decode_content,
#     603                                        flush_decoder=False)
#
# ~/git/plopezgarcia/trec-2018-precision-medicine/python/venv/lib/python3.5/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     555             self.chunk_left = None
#     556         elif amt < self.chunk_left:
# --> 557             value = self._fp._safe_read(amt)
#     558             self.chunk_left = self.chunk_left - amt
#     559             returned_chunk = value
#
# /usr/lib/python3.5/http/client.py in _safe_read(self, amt)
#     605         s = []
#     606         while amt > 0:
# --> 607             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     608             if not chunk:
#     609                 raise IncompleteRead(b''.join(s), amt)
#
# /usr/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
results

# %% [markdown]
# ## Load and split TOPICS and GOLD STANDARD from last year (30 topics)
# Also, split them into training, test, and development set.

# %%
topics_train, topics_test, topics_dev = utils.split_topics(topics_all)
qrels_train, qrels_test, qrels_dev = utils.split_qrels(qrels_all, topics_train, topics_test, topics_dev)

# %%
assert(set([topic for topic in topics_train['topic']])==set([topic for topic in qrels_train['topic']]))
assert(set([topic for topic in topics_test['topic']])==set([topic for topic in qrels_test['topic']]))
assert(set([topic for topic in topics_dev['topic']])==set([topic for topic in qrels_dev['topic']]))

# %% [markdown]
# ### Example runs

# %%
full_run_params = running.get_default_run_params()
full_run_params['query_template'] = 'baseline.json'
full_run_df, full_run_params = running.run(topics_all)
results, aggregated = evaluation.evaluate(qrels_all, full_run_df)
aggregated
#assert(aggregated['ndcg'] == 0.5338)
#{'P_10': 0.48, 'Rprec': 0.2847, 'ndcg': 0.5338, 'recall_1000': 0.6139}
# Out:
# RUN: DEFAULT_RUN TOPICS: 30 {'run_id': 'DEFAULT_RUN', 'gene_tie_breaker': 0.5, 'gene_boost': 1, 'query_template': 'baseline.json', 'disease_tie_breaker': 0.5, 'disease_boost': 1.5}
# {'P_10': 0.48, 'Rprec': 0.2847, 'ndcg': 0.5338, 'recall_1000': 0.6139}

# %%
run_params = running.get_default_run_params()
run_params['query_template'] = 'fixed/baseline_sex_age.json'
full_run_df, run_params = running.run(topics_all)
results, aggregated = evaluation.evaluate(qrels_all, full_run_df)
aggregated
# Only MeSH, best fields: {'P_10': 0.5167, 'Rprec': 0.2785, 'ndcg': 0.5383, 'recall_1000': 0.6148}
# Only MeSH, cross fields: {'P_10': 0.5067, 'Rprec': 0.2811, 'ndcg': 0.5413, 'recall_1000': 0.6159}
# Only MeSH, cross, best: {'P_10': 0.52, 'Rprec': 0.2814, 'ndcg': 0.5378, 'recall_1000': 0.6151}
# Only MeSH, best, cross: {'P_10': 0.52, 'Rprec': 0.2787, 'ndcg': 0.5417, 'recall_1000': 0.6173} ***** best ndcg, best P_10
# Out:
# RUN: DEFAULT_RUN TOPICS: 30
# {'P_10': 0.52, 'Rprec': 0.2787, 'ndcg': 0.5417, 'recall_1000': 0.6173}

# %%
run_params = running.get_default_run_params()
run_params['query_template'] = 'fixed/baseline_sex_age_all_fields.json'
full_run_df, run_params = running.run(topics_all)
results, aggregated = evaluation.evaluate(qrels_all, full_run_df)
aggregated
# All fields, best fields: {'P_10': 0.51, 'Rprec': 0.2744, 'ndcg': 0.5396, 'recall_1000': 0.6143}
# All fields, cross fields: {'P_10': 0.5067, 'Rprec': 0.281, 'ndcg': 0.5412, 'recall_1000': 0.6157}
# All fields, best fields disease, gene, cross fields rest: {'P_10': 0.5167, 'Rprec': 0.276, 'ndcg': 0.5378, 'recall_1000': 0.6139}
# All fields, best fields disease, cross fields rest: {'P_10': 0.52, 'Rprec': 0.278, 'ndcg': 0.5416, 'recall_1000': 0.6174} ***** best ndcg, best P_10
# Out:
# RUN: DEFAULT_RUN TOPICS: 30
# {'P_10': 0.52, 'Rprec': 0.278, 'ndcg': 0.5416, 'recall_1000': 0.6174}

# %%
#full_run_df

# %% [markdown]
# Test run with default_params

# %%
training_run_df, training_run_params = running.run(topics_train)
# Out:
# RUN: DEFAULT_RUN TOPICS: 12 {'run_id': 'DEFAULT_RUN', 'disease_tie_breaker': 0.5, 'gene_boost': 1, 'gene_tie_breaker': 0.5, 'query_template': 'baseline.json', 'disease_boost': 1.5}

# %%
training_results, training_aggregated = evaluation.evaluate(qrels_train, training_run_df)
training_score = pandas.Series(training_aggregated, name='training ' + '(' + str(len(topics_train)) + ' topics)')

# %%
test_run_df, test_run_params = running.run(topics_test, training_run_params)
# Out:
# RUN: DEFAULT_RUN TOPICS: 9 {'run_id': 'DEFAULT_RUN', 'disease_tie_breaker': 0.5, 'gene_boost': 1, 'gene_tie_breaker': 0.5, 'query_template': 'baseline.json', 'disease_boost': 1.5}

# %%
training_score
# Out:
# P_10           0.4333
# Rprec          0.2810
# ndcg           0.5383
# recall_1000    0.6650
# Name: training (12 topics), dtype: float64

# %%
test_results, test_aggregated = evaluation.evaluate(qrels_test, test_run_df)
test_score = pandas.Series(test_aggregated, name='test ' + '(' + str(len(topics_test)) + ' topics)')

# %%
pandas.DataFrame([training_score, test_score])
# Out:
#                         P_10   Rprec    ndcg  recall_1000
# training (12 topics)  0.4333  0.2810  0.5383       0.6650
# test (9 topics)       0.3556  0.2194  0.4820       0.5423
